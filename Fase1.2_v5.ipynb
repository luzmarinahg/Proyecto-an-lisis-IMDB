# %%
# Importar librerías para tratamiento de datos
# -----------------------------------------------------------------------
import pandas as pd  # Pandas es una poderosa librería para manipulación y análisis de datos en Python.

# Importar librerías para web scraping y manipulación de datos
# -----------------------------------------------------------------------
import requests

# Importar librerías para automatización de navegadores web con Selenium
# -----------------------------------------------------------------------
from selenium import webdriver  # Selenium es una herramienta para automatizar la interacción con navegadores web.
from webdriver_manager.chrome import ChromeDriverManager  # ChromeDriverManager gestiona la instalación del controlador de Chrome.
from selenium.webdriver.common.keys import Keys  # Keys es útil para simular eventos de teclado en Selenium.
from selenium.webdriver.support.ui import Select  # Select se utiliza para interactuar con elementos <select> en páginas web.

# Importar librerías para pausar la ejecución
# -----------------------------------------------------------------------
from time import sleep  # Sleep se utiliza para pausar la ejecución del programa por un número de segundos.

# Importar tqdm para ver el progreso la ejecución
from tqdm import tqdm

# Configuraciones
# -----------------------------------------------------------------------
pd.set_option('display.max_columns', None)  # Establece una opción de Pandas para mostrar todas las columnas de un DataFrame.

# %%
# Prueba con find.elements()

movie_list = []
movie_tuple = ()

# función para importar el archivo csv y convertirlo a DF
def import_csv(csv):
    # - Importar los datos del CSV de las películas y convertirlo a dataframe
    df_completo = pd.read_csv(csv)
    # - filtrar solo las películas.
    df_movies = df_completo[df_completo["type"].isin(["Movie", "Short"])]
    print("We have imported the movies and shorts of the csv file")
    return df_movies

# función para inicializar el driver y rechazar cookies
def init_driver(url):
    driver = webdriver.Chrome()
    driver.get(url)
    sleep(2)
    driver.find_element("css selector", '#__next > div > div > div.sc-jrcTuL.bPmWiM > div > button.icb-btn.sc-bcXHqe.sc-hLBbgP.sc-ftTHYK.dcvrLS.dufgkr.ecppKW').click()
    print("Hemos rechazado las cookies")
    return driver 

#funcion para recoger toda la información y almacenarla en una tupla
id_list = []
def collect_data(driver, id):
    if id in id_list: # condicional por si la pelicula ya está recogida, ignora los duplicados
        pass # chatty aquí tiene return None, y no pone el else: Supongo que simplifica el código
    else:
        driver.find_element("xpath", '//*[@id="suggestion-search"]').send_keys(id, Keys.ENTER)
        print("We have accessed the movie")
        sleep(3) #dar tiempo para que cargue la pagina

        # si no está la pag de la peli maximizada no se ve el plot completo y solo extrae lo que se ve, que muchas veces incluye ...Read all
        driver.maximize_window() 

        
        # Empezar a recoger información

        #Rating
        try:
            IMDB_rating = driver.find_element("xpath", '//*[@id="__next"]/main/div/section[1]/section/div[3]/section/section/div[2]/div[2]/div/div[1]/a/span/div/div[2]/div[1]/span[1]').text
            print("We have accessed to the IMDB_rating")
            sleep(2)
        except:
            if not IMDB_rating: # en caso de que no haya puntuación
                IMDB_rating = None
                print("We could not access the rating")                         

        # directoras. BTW: me parece que se pueden contar con los dedos de una mano...
        directors = []
        all_directors = driver.find_elements('xpath', '//*[@id="__next"]/main/div/section[1]/section/div[3]/section/section/div[3]/div[2]/div[1]/section/div[2]/div/ul/li[1]/div/ul/li/a')

        for i in range(len(all_directors)):
            directors.append(all_directors[i].get_attribute('innerHTML'))
    
       
        # guionistas    
        writers = []
        all_writers = driver.find_elements("xpath", '//*[@id="__next"]/main/div/section[1]/section/div[3]/section/section/div[3]/div[2]/div[2]/div[2]/div/ul/li[2]/div/ul/li/a')
        for i in range(len(all_writers)):
            writers.append(all_writers[i].get_attribute('innerHTML'))                   

        # argumento
        try: 
            plot = driver.find_element("xpath", '//*[@id="__next"]/main/div/section[1]/section/div[3]/section/section/div[3]/div[2]/div[1]/section/p').text
            print("We have accessed to the plot")
            sleep(2)
        except:
            if not plot:
                plot = None
                print("We could not access the plot ")
            elif plot == "Add a plot":
                plot = None
                print("There was no plot described")

        # duración de la peli
                  
        year = None
        rate_age = None
        lenght = None
        all_others_data = driver.find_elements('xpath', '//*[@id="__next"]/main/div/section[1]/section/div[3]/section/section/div[2]/div[1]/ul/li')
        if len(all_others_data) == 2:
            year = all_others_data[0].find_element('css selector','a').get_attribute('innerHTML')
            lenght = all_others_data[1].get_attribute('innerHTML')
        elif len(all_others_data) == 3:
            year = all_others_data[0].find_element('css selector','a').get_attribute('innerHTML')
            rate_age = all_others_data[1].find_element('css selector','a').get_attribute('innerHTML')
            lenght = all_others_data[2].get_attribute('innerHTML')
        else:
            print(f'REVISAR - La pelicula con id {id} tiene {len(all_others_data)} variables')
        # nombre
        try:
            name = driver.find_element("xpath", '//*[@id="__next"]/main/div/section[1]/section/div[3]/section/section/div[2]/div[1]/h1/span').text
            print(f"We have accessed to the movie name - {name}")
            sleep(5)
        except:
            if not name:
                name = None
                print("We could not access the movie name")
        
        # añadir el idOwner de esta película a la lista, para que no la repita
        id_list.append(id)

        movie_tuple = (id, IMDB_rating, directors, writers, plot, lenght, name, year,rate_age)
        sleep(2)
        return movie_tuple
    

#funcion para añadir cada tupla a la lista de películas
def add_movie_tuple(movie_tuple):
    if movie_tuple in movie_list:
        pass
    else:
        movie_list.append(movie_tuple)
    return movie_list

# función para ciclar sobre los idOwner de df_movies
def loop_movies(driver, df_movies):
    for id in df_movies["idOwner"][:100]: #Se reduce el buble en 100 peliculas para no tardar tanto en la estraccion
        movie_tuple = collect_data(driver, id)
        add_movie_tuple(movie_tuple)

# %%
# Bloque para Ejecutar todas las funciones de arriba
url = "https://www.imdb.com/?ref_=nv_home"
csv = "Team1_API_extraction.csv"
driver = init_driver(url)
df_movies = import_csv(csv)
loop_movies(driver, df_movies)
# Out:
# Hemos rechazado las cookies
# We have imported the movies and shorts of the csv file
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name - A todo riesgo
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name - Three Came to Kill
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name - Las dos caras del destino
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name - El círculo rojo
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name - El robo al banco de Inglaterra
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name - La Llorona
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name - Meurtre en 45 tours
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name - La Liga de los caballeros
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name - Los jóvenes
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name - Huída a Berlin
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name - Servicio secreto
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name - Caccia all'uomo
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name - La maldición de Nostradamus
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name - The Cat Burglar
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name - Bloodlust!
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name - Doctor Blood's Coffin
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name - Five Minutes to Live
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name - Cash on Demand
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name - Los autómatas de la muerte
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name - La mentira tiene cabellos rojos
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name - Il criminale
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 6
#       4 driver = init_driver(url)
#       5 df_movies = import_csv(csv)
# ----> 6 loop_movies(driver, df_movies)
#
# Cell In[12], line 121, in loop_movies(driver, df_movies)
#     119 def loop_movies(driver, df_movies):
#     120     for id in df_movies["idOwner"][:100]: #FIJATE que aquí reduje el bucle para que solo recoja info de 3 o 4 películas
# --> 121         movie_tuple = collect_data(driver, id)
#     122         add_movie_tuple(movie_tuple)
#
# Cell In[12], line 106, in collect_data(driver, id)
#     103 id_list.append(id)
#     105 movie_tuple = (id, IMDB_rating, directors, writers, plot, lenght, name, year,rate_age)
# --> 106 sleep(2)
#     107 return movie_tuple
#
# KeyboardInterrupt:

# %%
# comprobar qué información se recogió
for tuple in movie_list:
    print(tuple)
# Out:
# ('tt0052698', '7,5', ['Claude Sautet'], ['José Giovanni', 'Claude Sautet', 'Pascal Jardin'], 'Un despiadado criminal huye de la persecución, lo que implica cada vez más víctimas.', '1h 50min', 'A todo riesgo', '1960', 'Not Rated')
# ('tt0053357', '5,5', ['Edward L. Cahn'], ['Robert E. Kent', 'Orville H. Hampton'], 'Tres asesinos profesionales irrumpen en la casa de un empleado del aeropuerto para disparar al avión en el que un primer ministro asiático debe abandonar Estados Unidos.', '1h 11min', 'Three Came to Kill', '1960', 'Approved')
# ('tt0052661', '6,1', ['Alfred Weidenmann'], ['Herbert Reinecker', 'Igor Sentjurc'], 'Añade un argumento en tu idioma', '1h 32min', 'Las dos caras del destino', '1960', None)
# ('tt0053228', '6,2', ['Jürgen Roland'], ['Edgar Wallace', 'Egon Eis', 'Wolfgang Menge'], 'Añade un argumento en tu idioma\nA strange, red circle appears on the neck of a man saved from the guillotine. What is its mysterious meaning? Tragically, it turns out to be something of a family curse, as each generation thereafter bears the same sign, which in turn leads to blackmail and murder.', '1h 32min', 'El círculo rojo', '1960', None)
# ('tt0053752', '6,6', ['John Guillermin'], ['John Brophy', 'Howard Clewes', 'Richard Maibaum'], 'Añade un argumento en tu idioma\nIn 1901, a group of IRA members decides to rob the Bank of England in order to finance their movement and to embarrass the British government.', '1h 25min', 'El robo al banco de Inglaterra', '1960', 'Approved')
# ('tt0051874', '5,8', ['René Cardona'], ['Adolfo Torres Portillo', 'Carmen Toscano'], 'Felipe y Margarita se casan y tienen al pequeño Jorgito, y su tío Gerardo les cuenta la maldición que acecha al primer hijo de la familia.', '1h 15min', 'La Llorona', '1960', None)
# ('tt0053063', '5,9', ['Etienne Périer'], ['Pierre Boileau', 'Thomas Narcejac', 'Dominique Fabre'], "Añade un argumento en tu idioma\n(1961) Danielle Darrieux, Michael Auclair. A singer believes she's being haunted by the ghost of her dead husband.", '1h 33min', 'Meurtre en 45 tours', '1960', None)
# ('tt0052997', '7,2', ['Basil Dearden'], ['Bryan Forbes', 'John Boland'], 'Un veterano descontento recluta a un grupo de colegas caídos en desgracia para realizar un atraco a un banco con precisión militar.', '1h 56min', 'La Liga de los caballeros', '1960', 'Unrated')
# None
# ('tt0053979', '6,3', ['Luis Alcoriza'], ['Luis Alcoriza'], 'Añade un argumento en tu idioma\nLorenzo Gómez, "El Gato" and his gang, assault the car where Alicia and a boy were kissing each other.', '1h 40min', 'Los jóvenes', '1961', None)
# ('tt0053829', '6,6', ['Will Tremper'], ['Will Tremper'], 'Añade un argumento en tu idioma\nAn East German farmer is being harassed by SED (Sozialistische Einheitspartei Deutschlands) superiors since he is no longer willing to submit to the forced collectivization. He plans to flee to the West.', '1h 44min', 'Huída a Berlin', '1961', None)
# ('tt0054071', '7,2', ['Pierre Grimblat'], ['Pierre Grimblat', 'Jean-Michel Sorel', 'François Truffaut'], "Añade un argumento en tu idioma\nA down-on-his-luck reporter is framed on espionage charges by the government after taking some photos the government didn't want made public. He finds that in order to clear himself he has to transport some highly classified microfilm and find out who the spy is in the government who has been giving secret information about missile sites to the enemy.", '1h 25min', 'Servicio secreto', '1961', None)
# ('tt0054712', '5,4', ['Riccardo Freda'], ['Marcello Coscia', 'Dino De Palma', 'Luciano Martino'], 'Añade un argumento en tu idioma\nItalian cinema version of the first part of Victor Hugo\'s classic novel "Les Miserables".', '1h 40min', "Caccia all'uomo", '1961', None)
# ('tt0054054', '5,1', ['Federico Curiel', 'Stillman Segar'], ['Federico Curiel', 'Alfredo Ruanova', 'Carlos Enrique Taboada'], 'Añade un argumento en tu idioma\nAn aristocratic vampire swears an oath to kill the enemies who killed his father. In order to terrify them even further, he warns each one when he is coming for them.', '1h 18min', 'La maldición de Nostradamus', '1961', None)
# ('tt0054733', '5,9', ['William Witney'], ['Leo Gordon'], 'Añade un argumento en tu idioma\nA burglar steals a briefcase. Unknown to him, it contains a valuable secret formula. So he has the police on his trail--plus the owner of the formula and a ruthless spy...', '1h 5min', 'The Cat Burglar', '1961', 'Approved')
# ('tt0054691', '3,6', ['Ralph Brooke'], ['Ralph Brooke', 'Richard Connell'], 'Añade un argumento en tu idioma\nA crazed hunter kidnaps people and turns them loose on his private estate, where he hunts them for sport.', '1h 8min', 'Bloodlust!', '1961', 'Approved')
# ('tt0054823', '4,9', ['Sidney J. Furie'], ['Nathan Juran', 'James Kelley', 'Peter Miller'], 'Añade un argumento en tu idioma\nPeople are mysteriously disappearing near a remote Cornish village, where a scientist is experimenting; reviving the dead.', '1h 32min', "Doctor Blood's Coffin", '1961', 'Unrated')
# ('tt0054817', '5,5', ['Bill Karn'], ['Cay Forester', 'Palmer Thompson', 'Robert L. Joseph'], 'Añade un argumento en tu idioma\nA murderous thug and his cohorts take a bank executives wife hostage after their robbery plans go awry.', '1h 20min', 'Five Minutes to Live', '1961', 'Approved')
# ('tt0054731', '7,5', ['Quentin Lawrence'], ['David T. Chantler', 'Lewis Greifer', 'Jacques Gillies'], 'Añade un argumento en tu idioma\nA charming but ruthless criminal holds the family of a bank manager hostage as part of a cold-blooded plan to steal 97,000 pounds.', '1h 29min', 'Cash on Demand', '1961', 'Approved')
# ('tt0053615', '3,6', ['Federico Curiel'], ['Federico Curiel', 'Alfredo Ruanova'], "Añade un argumento en tu idioma\nThe evil scientist Dr. Caronte plots to revive the brains of three dead scientists and use them to obtain the formula for the super-powerful neutron bomb. The resulting creation needs blood lots of blood, sending Caronte's midget assistant Nick and his legion of mutant monsters out to get fresh victims. However, the masked atom-superman Neutron vows to put a stop to C... Leer todo", '1h 20min', 'Los autómatas de la muerte', '1962', None)
# ('tt0054078', '4,8', ['Antonio Isasi-Isasmendi'], ['Lluís Josep Comerón', 'Jorge Illa', 'Antonio Isasi-Isasmendi'], 'Añade un argumento en tu idioma\nIsabel and Enrique form a couple that get married after the success that they have obtained with a number of conjuring. But during the wedding night, the woman disappears mysteriously. Enrique gradually becomes convinced that his wife has abandoned him for another man.', '1h 35min', 'La mentira tiene cabellos rojos', '1962', None)

# %%
df_resultados = pd.DataFrame(movie_list, columns =["idOwner","IMDB_rating","direction","writers","plot","length","rate_age","year","name"])
df_resultados
# Out:
#       idOwner IMDB_rating                          direction  \
# 0   tt0052698         7,5                    [Claude Sautet]
# 1   tt0053357         5,5                   [Edward L. Cahn]
# 2   tt0052661         6,1                [Alfred Weidenmann]
# 3   tt0053228         6,2                    [Jürgen Roland]
# 4   tt0053752         6,6                  [John Guillermin]
# 5   tt0051874         5,8                     [René Cardona]
# 6   tt0053063         5,9                   [Etienne Périer]
# 7   tt0052997         7,2                    [Basil Dearden]
# 8        None        None                               None
# 9   tt0053979         6,3                    [Luis Alcoriza]
# 10  tt0053829         6,6                     [Will Tremper]
# 11  tt0054071         7,2                  [Pierre Grimblat]
# 12  tt0054712         5,4                   [Riccardo Freda]
# 13  tt0054054         5,1  [Federico Curiel, Stillman Segar]
# 14  tt0054733         5,9                   [William Witney]
# 15  tt0054691         3,6                     [Ralph Brooke]
# 16  tt0054823         4,9                  [Sidney J. Furie]
# 17  tt0054817         5,5                        [Bill Karn]
# 18  tt0054731         7,5                 [Quentin Lawrence]
# 19  tt0053615         3,6                  [Federico Curiel]
# 20  tt0054078         4,8          [Antonio Isasi-Isasmendi]
#
#                                               writers  \
# 0       [José Giovanni, Claude Sautet, Pascal Jardin]
# 1                [Robert E. Kent, Orville H. Hampton]
# 2                  [Herbert Reinecker, Igor Sentjurc]
# 3           [Edgar Wallace, Egon Eis, Wolfgang Menge]
# 4       [John Brophy, Howard Clewes, Richard Maibaum]
# 5            [Adolfo Torres Portillo, Carmen Toscano]
# 6   [Pierre Boileau, Thomas Narcejac, Dominique Fa...
# 7                         [Bryan Forbes, John Boland]
# 8                                                None
# 9                                     [Luis Alcoriza]
# 10                                     [Will Tremper]
# 11  [Pierre Grimblat, Jean-Michel Sorel, François ...
# 12  [Marcello Coscia, Dino De Palma, Luciano Martino]
# 13  [Federico Curiel, Alfredo Ruanova, Carlos Enri...
# 14                                       [Leo Gordon]
# 15                    [Ralph Brooke, Richard Connell]
# 16         [Nathan Juran, James Kelley, Peter Miller]
# 17  [Cay Forester, Palmer Thompson, Robert L. Joseph]
# 18  [David T. Chantler, Lewis Greifer, Jacques Gil...
# 19                 [Federico Curiel, Alfredo Ruanova]
# 20  [Lluís Josep Comerón, Jorge Illa, Antonio Isas...
#
#                                                  plot    length  \
# 0   Un despiadado criminal huye de la persecución,...  1h 50min
# 1   Tres asesinos profesionales irrumpen en la cas...  1h 11min
# 2                     Añade un argumento en tu idioma  1h 32min
# 3   Añade un argumento en tu idioma\nA strange, re...  1h 32min
# 4   Añade un argumento en tu idioma\nIn 1901, a gr...  1h 25min
# 5   Felipe y Margarita se casan y tienen al pequeñ...  1h 15min
# 6   Añade un argumento en tu idioma\n(1961) Daniel...  1h 33min
# 7   Un veterano descontento recluta a un grupo de ...  1h 56min
# 8                                                None      None
# 9   Añade un argumento en tu idioma\nLorenzo Gómez...  1h 40min
# 10  Añade un argumento en tu idioma\nAn East Germa...  1h 44min
# 11  Añade un argumento en tu idioma\nA down-on-his...  1h 25min
# 12  Añade un argumento en tu idioma\nItalian cinem...  1h 40min
# 13  Añade un argumento en tu idioma\nAn aristocrat...  1h 18min
# 14  Añade un argumento en tu idioma\nA burglar ste...   1h 5min
# 15  Añade un argumento en tu idioma\nA crazed hunt...   1h 8min
# 16  Añade un argumento en tu idioma\nPeople are my...  1h 32min
# 17  Añade un argumento en tu idioma\nA murderous t...  1h 20min
# 18  Añade un argumento en tu idioma\nA charming bu...  1h 29min
# 19  Añade un argumento en tu idioma\nThe evil scie...  1h 20min
# 20  Añade un argumento en tu idioma\nIsabel and En...  1h 35min
#
#                            rate_age  year       name
# 0                     A todo riesgo  1960  Not Rated
# 1                Three Came to Kill  1960   Approved
# 2         Las dos caras del destino  1960       None
# 3                   El círculo rojo  1960       None
# 4    El robo al banco de Inglaterra  1960   Approved
# 5                        La Llorona  1960       None
# 6               Meurtre en 45 tours  1960       None
# 7         La Liga de los caballeros  1960    Unrated
# 8                              None  None       None
# 9                       Los jóvenes  1961       None
# 10                   Huída a Berlin  1961       None
# 11                 Servicio secreto  1961       None
# 12                  Caccia all'uomo  1961       None
# 13      La maldición de Nostradamus  1961       None
# 14                  The Cat Burglar  1961   Approved
# 15                       Bloodlust!  1961   Approved
# 16            Doctor Blood's Coffin  1961    Unrated
# 17             Five Minutes to Live  1961   Approved
# 18                   Cash on Demand  1961   Approved
# 19       Los autómatas de la muerte  1962       None
# 20  La mentira tiene cabellos rojos  1962       None

# %%
#Convertimos en CSV
df_resultados.to_csv("film_details.csv",index=False)
