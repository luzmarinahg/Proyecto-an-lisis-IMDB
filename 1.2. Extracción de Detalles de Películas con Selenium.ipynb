# %%
# Importar librerías para tratamiento de datos
# -----------------------------------------------------------------------
import pandas as pd  # Pandas es una poderosa librería para manipulación y análisis de datos en Python.

# Importar librerías para web scraping y manipulación de datos
# -----------------------------------------------------------------------
import requests

# Importar librerías para automatización de navegadores web con Selenium
# -----------------------------------------------------------------------
from selenium import webdriver  # Selenium es una herramienta para automatizar la interacción con navegadores web.
from webdriver_manager.chrome import ChromeDriverManager  # ChromeDriverManager gestiona la instalación del controlador de Chrome.
from selenium.webdriver.common.keys import Keys  # Keys es útil para simular eventos de teclado en Selenium.
from selenium.webdriver.support.ui import Select  # Select se utiliza para interactuar con elementos <select> en páginas web.

# Importar librerías para pausar la ejecución
# -----------------------------------------------------------------------
from time import sleep  # Sleep se utiliza para pausar la ejecución del programa por un número de segundos.

# Importar tqdm para ver el progreso la ejecución
from tqdm import tqdm

# Configuraciones
# -----------------------------------------------------------------------
pd.set_option('display.max_columns', None)  # Establece una opción de Pandas para mostrar todas las columnas de un DataFrame.

# %%
# Creamos una lista vacia y una tupla 

movie_list = []
movie_tuple = ()

# Creamos una función para importar el archivo csv y convertirlo a DF
def import_csv(csv):
    # Importamos los datos del CSV de las películas y convertirlo a dataframe
    df_completo = pd.read_csv(csv)
    # Filtramos solo las películas.
    df_movies = df_completo[df_completo["type"].isin(["Movie", "Short"])]
    print("We have imported the movies and shorts of the csv file")
    return df_movies

# Iniciamos el driver y rechazamos las cookies
def init_driver(url):
    driver = webdriver.Chrome()
    driver.get(url)
    sleep(2)
    driver.find_element("css selector", '#__next > div > div > div.sc-jrcTuL.bPmWiM > div > button.icb-btn.sc-bcXHqe.sc-hLBbgP.sc-ftTHYK.dcvrLS.dufgkr.ecppKW').click()
    print("Hemos rechazado las cookies")
    return driver 

#Recogemos toda la información y almacenarla en una tupla
id_list = []
def collect_data(driver, id):
    if id in id_list: # Vemos si la pelicula ya está recogida, ignoramos los duplicados
        pass 
    else:
        driver.find_element("xpath", '//*[@id="suggestion-search"]').send_keys(id, Keys.ENTER)
        print("We have accessed the movie")
        sleep(3)

        # Maximizamos la ventana de la pagina
        driver.maximize_window() 

        
        # Empezar a recoger información

        #Rating
        IMDB_rating = None
        try:
            IMDB_rating = driver.find_element("xpath", '//*[@id="__next"]/main/div/section[1]/section/div[3]/section/section/div[2]/div[2]/div/div[1]/a/span/div/div[2]/div[1]/span[1]').text
            print("We have accessed to the IMDB_rating")
            sleep(2)
            
        except:
            if not IMDB_rating: # en caso de que no haya puntuación
                print("We could not access the rating")                         

        # Directoras/es
        directors = []
        all_directors = driver.find_elements('xpath', '//*[@id="__next"]/main/div/section[1]/section/div[3]/section/section/div[3]/div[2]/div[1]/section/div[2]/div/ul/li[1]/div/ul/li/a')

        for i in range(len(all_directors)):
            directors.append(all_directors[i].get_attribute('innerHTML'))
    
       
        # Guionistas    
        writers = []
        all_writers = driver.find_elements("xpath", '//*[@id="__next"]/main/div/section[1]/section/div[3]/section/section/div[3]/div[2]/div[2]/div[2]/div/ul/li[2]/div/ul/li/a')
        for i in range(len(all_writers)):
            writers.append(all_writers[i].get_attribute('innerHTML'))                   

        # Argumento
        plot = None
        try: 
            plot = driver.find_element("xpath", '//*[@id="__next"]/main/div/section[1]/section/div[3]/section/section/div[3]/div[2]/div[1]/section/p').text
            print("We have accessed to the plot")
            sleep(2)
        except:
            if not plot:
                plot = None
                print("We could not access the plot")
            elif plot == "Add a plot":
                print("There was no plot described")

        # Duración de la película
                  
        year = None
        rate_age = None
        lenght = None
        all_others_data = driver.find_elements('xpath', '//*[@id="__next"]/main/div/section[1]/section/div[3]/section/section/div[2]/div[1]/ul/li')
        if len(all_others_data) == 2:
            year = all_others_data[0].find_element('css selector','a').get_attribute('innerHTML')
            lenght = all_others_data[1].get_attribute('innerHTML')
        elif len(all_others_data) == 3:
            year = all_others_data[0].find_element('css selector','a').get_attribute('innerHTML')
            rate_age = all_others_data[1].find_element('css selector','a').get_attribute('innerHTML')
            lenght = all_others_data[2].get_attribute('innerHTML')
        else:
            print(f'REVISAR - La pelicula con id {id} tiene {len(all_others_data)} variables')
        
        
        # Nombre
        try:
            name = driver.find_element("xpath", '//*[@id="__next"]/main/div/section[1]/section/div[3]/section/section/div[2]/div[1]/h1/span').text
            print("We have accessed to the movie name") 
            sleep(5)
        except:
            if not name:
                name = None
                print("We could not access the movie name")
        
        # Añadimos el idOwner de esta película a la lista, para que no la repita
        id_list.append(id)

        movie_tuple = (id, IMDB_rating, directors, writers, plot, lenght, name, year)
        sleep(2)
        return movie_tuple
    

#Añadimos cada tupla a la lista de películas
def add_movie_tuple(movie_tuple):
    if movie_tuple in movie_list:
        pass
    else:
        movie_list.append(movie_tuple)
    return movie_list

# Ciclamos sobre los idOwner de df_movies
def loop_movies(driver, df_movies):
    for idx, id in enumerate(df_movies["idOwner"].unique()):
        print(f"{idx} - {id}")
        movie_tuple = collect_data(driver, id)
        add_movie_tuple(movie_tuple)

# %%
# Bloque para Ejecutar todas las funciones de arriba
url = "https://www.imdb.com/?ref_=nv_home"
csv = "Team1_API_extraction.csv"
driver = init_driver(url)
df_movies = import_csv(csv)
loop_movies(driver, df_movies)
# Out:
# Hemos rechazado las cookies
# We have imported the movies and shorts of the csv file
# 0 - tt0052698
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 1 - tt0053357
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 2 - tt0052661
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 3 - tt0053228
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 4 - tt0053752
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 5 - tt0051874
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 6 - tt0053063
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 7 - tt0052997
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 8 - tt0053979
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 9 - tt0053829
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 10 - tt0054071
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 11 - tt0054712
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 12 - tt0054054
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 13 - tt0054733
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 14 - tt0054691
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 15 - tt0054823
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 16 - tt0054817
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 17 - tt0054731
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 18 - tt0053615
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 19 - tt0054078
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 20 - tt0054401
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 21 - tt0054821
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 22 - tt0054668
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 23 - tt0055783
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 24 - tt0054913
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 25 - tt0055824
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 26 - tt0055887
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 27 - tt0054730
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 28 - tt0054887
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 29 - tt0055863
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 30 - tt0055128
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 31 - tt0055021
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 32 - tt0056925
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 33 - tt0056923
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 34 - tt0057332
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 35 - tt0057076
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 36 - tt0056459
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 37 - tt0055953
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 38 - tt0057498
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 39 - tt0057082
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 40 - tt0057938
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 41 - tt0057924
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 42 - tt0057908
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 43 - tt0058011
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 44 - tt0058049
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 45 - tt0057148
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 46 - tt0057485
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 47 - tt0057926
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 48 - tt0057948
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 49 - tt0057972
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 50 - tt0057857
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 51 - tt0058216
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 52 - tt0058610
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 53 - tt0058381
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 54 - tt0058865
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 55 - tt0058359
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 56 - tt0058878
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 57 - tt0060044
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 58 - tt0059013
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# REVISAR - La pelicula con id tt0059013 tiene 1 variables
# We have accessed to the movie name
# 59 - tt0059648
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 60 - tt0059935
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 61 - tt0060052
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 62 - tt0060295
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 63 - tt0056855
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 64 - tt0060093
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 65 - tt0060374
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 66 - tt0060134
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# REVISAR - La pelicula con id tt0060134 tiene 1 variables
# We have accessed to the movie name
# 67 - tt0060796
# We have accessed the movie
# We could not access the rating
# We have accessed to the plot
# We have accessed to the movie name
# 68 - tt0060944
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 69 - tt0060326
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 70 - tt0060676
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 71 - tt0060288
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 72 - tt0057858
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 73 - tt0060265
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 74 - tt0060226
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 75 - tt0061952
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 76 - tt0061946
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 77 - tt0061864
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 78 - tt0061054
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 79 - tt0061340
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 80 - tt0061459
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 81 - tt0058968
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 82 - tt0061453
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 83 - tt0061432
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 84 - tt0061580
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 85 - tt0062255
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 86 - tt0062438
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 87 - tt0062769
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 88 - tt0062836
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 89 - tt0061494
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 90 - tt0063309
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 91 - tt0063696
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 92 - tt0064126
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 93 - tt0063552
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 94 - tt0064106
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 95 - tt0064177
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 96 - tt0064413
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 97 - tt0064225
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 98 - tt0064630
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 99 - tt0060939
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 100 - tt0063244
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 101 - tt0064451
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 102 - tt0065735
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 103 - tt0065770
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 104 - tt0065761
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 105 - tt0065619
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 106 - tt0064143
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 107 - tt0065424
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 108 - tt0066192
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 109 - tt0066756
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 110 - tt0066939
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 111 - tt0067015
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 112 - tt0066982
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 113 - tt0067052
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 114 - tt0060951
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 115 - tt0066156
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 116 - tt0065574
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 117 - tt0068236
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 118 - tt0068547
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 119 - tt0069270
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 120 - tt0068488
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 121 - tt0068724
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 122 - tt0068382
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 123 - tt0069041
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 124 - tt0068457
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 125 - tt0069243
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 126 - tt0069435
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 127 - tt0069022
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 128 - tt0069241
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 129 - tt0068904
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 130 - tt0069909
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 131 - tt0069735
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 132 - tt0069930
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 133 - tt0070031
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 134 - tt0070312
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 135 - tt0070834
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 136 - tt0070636
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 137 - tt0070556
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 138 - tt0071164
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 139 - tt0071099
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 140 - tt0071297
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 141 - tt0052259
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 142 - tt0052721
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 143 - tt0053056
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 144 - tt0053768
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 145 - tt0053598
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 146 - tt0053623
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 147 - tt0053693
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 148 - tt0054005
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 149 - tt0053786
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 150 - tt0054013
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 151 - tt0054850
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 152 - tt0054672
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 153 - tt0054618
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 154 - tt0054739
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 155 - tt0054854
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 156 - tt0054860
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 157 - tt0054649
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 158 - tt0054638
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 159 - tt0053694
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 160 - tt0054665
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 161 - tt0054637
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 162 - tt0054893
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 163 - tt0054811
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 164 - tt0055924
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 165 - tt0056257
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 166 - tt0055564
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 167 - tt0055988
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 168 - tt0055946
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 169 - tt0054382
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 170 - tt0055802
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# REVISAR - La pelicula con id tt0055802 tiene 1 variables
# We have accessed to the movie name
# 171 - tt0056343
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 172 - tt0056844
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 173 - tt0056950
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 174 - tt0056824
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 175 - tt0057036
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 176 - tt0057019
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 177 - tt0057009
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 178 - tt0057404
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 179 - tt0057897
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 180 - tt0057894
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 181 - tt0057865
# We have accessed the movie
# We could not access the rating
# We have accessed to the plot
# REVISAR - La pelicula con id tt0057865 tiene 1 variables
# We have accessed to the movie name
# 182 - tt0054240
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 183 - tt0058662
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 184 - tt0058374
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 185 - tt0058423
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 186 - tt0059172
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 187 - tt0059557
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 188 - tt0059604
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 189 - tt0059495
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 190 - tt0059032
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 191 - tt0059222
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 192 - tt0060104
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 193 - tt0059010
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 194 - tt0060718
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 195 - tt0060938
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 196 - tt0060966
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 197 - tt0060400
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 198 - tt0061790
# We have accessed the movie
# We could not access the rating
# We have accessed to the plot
# We have accessed to the movie name
# 199 - tt0060108
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 200 - tt0060379
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 201 - tt0061561
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 202 - tt0061643
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 203 - tt0062503
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 204 - tt0062729
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 205 - tt0062803
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 206 - tt0062737
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 207 - tt0063023
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 208 - tt0062743
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 209 - tt0063340
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 210 - tt0063699
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 211 - tt0063216
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 212 - tt0064258
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 213 - tt0064443
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 214 - tt0064425
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 215 - tt0060477
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 216 - tt0062701
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 217 - tt0064190
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 218 - tt0064843
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 219 - tt0065050
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 220 - tt0064806
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 221 - tt0064932
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 222 - tt0064554
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 223 - tt0065073
# We have accessed the movie
# We have accessed to the IMDB_rating
# We have accessed to the plot
# We have accessed to the movie name
# 224 - tt0064430
# We have accessed the movie
# We could not access the rating
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[40], line 67, in collect_data(driver, id)
#      66 try:
# ---> 67     plot = driver.find_element("xpath", '//*[@id="__next"]/main/div/section[1]/section/div[3]/section/section/div[3]/div[2]/div[1]/section/p').text
#      68     print("We have accessed to the plot")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\selenium\webdriver\remote\webdriver.py:741, in WebDriver.find_element(self, by, value)
#     739     value = f'[name="{value}"]'
# --> 741 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\selenium\webdriver\remote\webdriver.py:347, in WebDriver.execute(self, driver_command, params)
#     346 if response:
# --> 347     self.error_handler.check_response(response)
#     348     response["value"] = self._unwrap_value(response.get("value", None))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\selenium\webdriver\remote\errorhandler.py:229, in ErrorHandler.check_response(self, response)
#     228     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="__next"]/main/div/section[1]/section/div[3]/section/section/div[3]/div[2]/div[1]/section/p"}
#   (Session info: chrome=126.0.6478.128); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF6D1BCEEB2+31554]
# 	(No symbol) [0x00007FF6D1B47EE9]
# 	(No symbol) [0x00007FF6D1A0872A]
# 	(No symbol) [0x00007FF6D1A58434]
# 	(No symbol) [0x00007FF6D1A5853C]
# 	(No symbol) [0x00007FF6D1A9F6A7]
# 	(No symbol) [0x00007FF6D1A7D06F]
# 	(No symbol) [0x00007FF6D1A9C977]
# 	(No symbol) [0x00007FF6D1A7CDD3]
# 	(No symbol) [0x00007FF6D1A4A33B]
# 	(No symbol) [0x00007FF6D1A4AED1]
# 	GetHandleVerifier [0x00007FF6D1ED8B2D+3217341]
# 	GetHandleVerifier [0x00007FF6D1F25AF3+3532675]
# 	GetHandleVerifier [0x00007FF6D1F1B0F0+3489152]
# 	GetHandleVerifier [0x00007FF6D1C7E786+750614]
# 	(No symbol) [0x00007FF6D1B5376F]
# 	(No symbol) [0x00007FF6D1B4EB24]
# 	(No symbol) [0x00007FF6D1B4ECB2]
# 	(No symbol) [0x00007FF6D1B3E17F]
# 	BaseThreadInitThunk [0x00007FFD7FF87604+20]
# 	RtlUserThreadStart [0x00007FFD802626A1+33]
#
#
# During handling of the above exception, another exception occurred:
#
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[43], line 6
#       4 driver = init_driver(url)
#       5 df_movies = import_csv(csv)
# ----> 6 loop_movies(driver, df_movies)
#
# Cell In[40], line 125, in loop_movies(driver, df_movies)
#     123 for idx, id in enumerate(df_movies["idOwner"].unique()):
#     124     print(f"{idx} - {id}")
# --> 125     movie_tuple = collect_data(driver, id)
#     126     add_movie_tuple(movie_tuple)
#
# Cell In[40], line 71, in collect_data(driver, id)
#      69     sleep(2)
#      70 except:
# ---> 71     if not plot:
#      72         plot = None
#      73         print("We could not access the plot")
#
# UnboundLocalError: cannot access local variable 'plot' where it is not associated with a value

# %%
print(len(movie_list))
# Out:
# 224

# %%
# Comprobamos qué información se recogió
for tuple in movie_list:
    print(tuple)
# Out:
# ('tt0052698', '7,5', ['Claude Sautet'], ['José Giovanni', 'Claude Sautet', 'Pascal Jardin'], 'Un despiadado criminal huye de la persecución, lo que implica cada vez más víctimas.', '1h 50min', 'A todo riesgo', '1960')
# ('tt0053357', '5,5', ['Edward L. Cahn'], ['Robert E. Kent', 'Orville H. Hampton'], 'Tres asesinos profesionales irrumpen en la casa de un empleado del aeropuerto para disparar al avión en el que un primer ministro asiático debe abandonar Estados Unidos.', '1h 11min', 'Three Came to Kill', '1960')
# ('tt0052661', '6,1', ['Alfred Weidenmann'], ['Herbert Reinecker', 'Igor Sentjurc'], 'Añade un argumento en tu idioma', '1h 32min', 'Las dos caras del destino', '1960')
# ('tt0053228', '6,2', ['Jürgen Roland'], ['Edgar Wallace', 'Egon Eis', 'Wolfgang Menge'], 'Añade un argumento en tu idioma\nA strange, red circle appears on the neck of a man saved from the guillotine. What is its mysterious meaning? Tragically, it turns out to be something of a family curse, as each generation thereafter bears the same sign, which in turn leads to blackmail and murder.', '1h 32min', 'El círculo rojo', '1960')
# ('tt0053752', '6,6', ['John Guillermin'], ['John Brophy', 'Howard Clewes', 'Richard Maibaum'], 'Añade un argumento en tu idioma\nIn 1901, a group of IRA members decides to rob the Bank of England in order to finance their movement and to embarrass the British government.', '1h 25min', 'El robo al banco de Inglaterra', '1960')
# ('tt0051874', '5,8', ['René Cardona'], ['Adolfo Torres Portillo', 'Carmen Toscano'], 'Felipe y Margarita se casan y tienen al pequeño Jorgito, y su tío Gerardo les cuenta la maldición que acecha al primer hijo de la familia.', '1h 15min', 'La Llorona', '1960')
# ('tt0053063', '5,9', ['Etienne Périer'], ['Pierre Boileau', 'Thomas Narcejac', 'Dominique Fabre'], "Añade un argumento en tu idioma\n(1961) Danielle Darrieux, Michael Auclair. A singer believes she's being haunted by the ghost of her dead husband.", '1h 33min', 'Meurtre en 45 tours', '1960')
# ('tt0052997', '7,2', ['Basil Dearden'], ['Bryan Forbes', 'John Boland'], 'Un veterano descontento recluta a un grupo de colegas caídos en desgracia para realizar un atraco a un banco con precisión militar.', '1h 56min', 'La Liga de los caballeros', '1960')
# ('tt0053979', '6,3', ['Luis Alcoriza'], ['Luis Alcoriza'], 'Añade un argumento en tu idioma\nLorenzo Gómez, "El Gato" and his gang, assault the car where Alicia and a boy were kissing each other.', '1h 40min', 'Los jóvenes', '1961')
# ('tt0053829', '6,6', ['Will Tremper'], ['Will Tremper'], 'Añade un argumento en tu idioma\nAn East German farmer is being harassed by SED (Sozialistische Einheitspartei Deutschlands) superiors since he is no longer willing to submit to the forced collectivization. He plans to flee to the West.', '1h 44min', 'Huída a Berlin', '1961')
# ('tt0054071', '7,2', ['Pierre Grimblat'], ['Pierre Grimblat', 'Jean-Michel Sorel', 'François Truffaut'], "Añade un argumento en tu idioma\nA down-on-his-luck reporter is framed on espionage charges by the government after taking some photos the government didn't want made public. He finds that in order to clear himself he has to transport some highly classified microfilm and find out who the spy is in the government who has been giving secret information about missile sites to the enemy.", '1h 25min', 'Servicio secreto', '1961')
# ('tt0054712', '5,4', ['Riccardo Freda'], ['Marcello Coscia', 'Dino De Palma', 'Luciano Martino'], 'Añade un argumento en tu idioma\nItalian cinema version of the first part of Victor Hugo\'s classic novel "Les Miserables".', '1h 40min', "Caccia all'uomo", '1961')
# ('tt0054054', '5,1', ['Federico Curiel', 'Stillman Segar'], ['Federico Curiel', 'Alfredo Ruanova', 'Carlos Enrique Taboada'], 'Añade un argumento en tu idioma\nAn aristocratic vampire swears an oath to kill the enemies who killed his father. In order to terrify them even further, he warns each one when he is coming for them.', '1h 18min', 'La maldición de Nostradamus', '1961')
# ('tt0054733', '5,9', ['William Witney'], ['Leo Gordon'], 'Añade un argumento en tu idioma\nA burglar steals a briefcase. Unknown to him, it contains a valuable secret formula. So he has the police on his trail--plus the owner of the formula and a ruthless spy...', '1h 5min', 'The Cat Burglar', '1961')
# ('tt0054691', '3,6', ['Ralph Brooke'], ['Ralph Brooke', 'Richard Connell'], 'Añade un argumento en tu idioma\nA crazed hunter kidnaps people and turns them loose on his private estate, where he hunts them for sport.', '1h 8min', 'Bloodlust!', '1961')
# ('tt0054823', '4,9', ['Sidney J. Furie'], ['Nathan Juran', 'James Kelley', 'Peter Miller'], 'Añade un argumento en tu idioma\nPeople are mysteriously disappearing near a remote Cornish village, where a scientist is experimenting; reviving the dead.', '1h 32min', "Doctor Blood's Coffin", '1961')
# ('tt0054817', '5,5', ['Bill Karn'], ['Cay Forester', 'Palmer Thompson', 'Robert L. Joseph'], 'Añade un argumento en tu idioma\nA murderous thug and his cohorts take a bank executives wife hostage after their robbery plans go awry.', '1h 20min', 'Five Minutes to Live', '1961')
# ('tt0054731', '7,5', ['Quentin Lawrence'], ['David T. Chantler', 'Lewis Greifer', 'Jacques Gillies'], 'Añade un argumento en tu idioma\nA charming but ruthless criminal holds the family of a bank manager hostage as part of a cold-blooded plan to steal 97,000 pounds.', '1h 29min', 'Cash on Demand', '1961')
# ('tt0053615', '3,6', ['Federico Curiel'], ['Federico Curiel', 'Alfredo Ruanova'], "Añade un argumento en tu idioma\nThe evil scientist Dr. Caronte plots to revive the brains of three dead scientists and use them to obtain the formula for the super-powerful neutron bomb. The resulting creation needs blood lots of blood, sending Caronte's midget assistant Nick and his legion of mutant monsters out to get fresh victims. However, the masked atom-superman Neutron vows to put a stop to C... Leer todo", '1h 20min', 'Los autómatas de la muerte', '1962')
# ('tt0054078', '4,8', ['Antonio Isasi-Isasmendi'], ['Lluís Josep Comerón', 'Jorge Illa', 'Antonio Isasi-Isasmendi'], 'Añade un argumento en tu idioma\nIsabel and Enrique form a couple that get married after the success that they have obtained with a number of conjuring. But during the wedding night, the woman disappears mysteriously. Enrique gradually becomes convinced that his wife has abandoned him for another man.', '1h 35min', 'La mentira tiene cabellos rojos', '1962')
# ('tt0054401', '6,5', ['Marcello Baldi'], ['Marcello Baldi', 'Elio Bartolini'], 'Añade un argumento en tu idioma\nA gritty little intrigue thriller with Palance as an ex-nazi doctor in hiding. While riding on a train, he is recognized by passengers who remember him from their prisoner of war camp days. One thing leads to another and when Palance is cornered, he commits murder! He then takes a girl hostage.', '1h 35min', 'Il criminale', '1962')
# ('tt0054821', '7,7', ['Jean-Pierre Melville'], ['Pierre Lesou', 'Jean-Pierre Melville'], 'Un ladrón que traiciona a otros criminales, prepara un gran golpe con un amigo de confianza que al final resulta ser poco fiable.', '1h 48min', 'El confidente', '1962')
# ('tt0054668', '5,0', ['Chano Urueta'], ['Federico Curiel', 'Adolfo López Portillo', 'Antonio Orellana'], "Añade un argumento en tu idioma\nIn 1661 Mexico, the Baron Vitelius of Astara is sentenced to be burned alive by the Holy Inquisition of Mexico for witchcraft, necromancy, and other crimes. As he dies, the Baron swears vengeance against the descendants of the Inquisitors. 300 years later, a comet which was passing overhead on the night of the Baron's execution returns to earth, bringing with it the B... Leer todo", '1h 17min', 'El barón del terror', '1962')
# ('tt0055783', '7,0', ['Biren Nag'], ['Dhruva Chatterjee', 'Dev Kishan'], "Añade un argumento en tu idioma\nWhen a young man's family gets haunted by a spirit, he is warned not to return to his hometown, but he decides to investigate the issue.", '2h 38min', 'Bees Saal Baad', '1962')
# ('tt0054913', '5,7', ['Werner Klingler'], ['Gustav Kampendonk', 'Bryan Edgar Wallace'], "Añade un argumento en tu idioma\nA killer who uses a knife is knocking off guests at a hotel in London's Soho district. A police detective is sent to investigate.", '1h 25min', 'El misterio de la maleta negra', '1962')
# ('tt0055824', '7,7', ['J. Lee Thompson'], ['John D. MacDonald', 'James R. Webb'], 'La familia de un abogado es acosada por un hombre al que ayudó a meter en la cárcel.', '1h 46min', 'El cabo del terror', '1962')
# ('tt0055887', '4,2', ['Robert Gottschalk'], ['Paul Strait', 'Robert Gottschalk'], 'Añade un argumento en tu idioma\nThe crew of a fishing boat discovers a deserted luxury yacht at sea with a dead body on board. They claim the yacht as salvage, not knowing that a drug smuggling ring has hidden $500,000 worth of heroin on the boat.', '1h 16min', 'Dangerous Charter', '1962')
# ('tt0054730', '5,2', ['Alfredo B. Crevenna', 'Alberto Mariscal'], ['Mario García Camberos', 'Alfredo Ruanova'], 'Añade un argumento en tu idioma', '1h 26min', 'La casa de los espantos', '1963')
# ('tt0054887', '6,0', ['János Veiczi'], ['Heinz Hafke', 'Hans Lucke', 'Harry Thürk'], 'Añade un argumento en tu idioma\nThe "Concordia" trading company in Würzburg is a secret headquarters of the MID, a secret service agency of the US Army. For years, espionage, sabotage, and diversion operations originated from here in order to undermine the Socialist Republic of Germany. A favorable moment for a military attack approaches and plans are developed. These plans are placed in the hands o... Leer todo', '1h 43min', 'Streng geheim', '1963')
# ('tt0055863', '5,4', ['José Bénazéraf'], ['Anne-Marie Devillers', 'Guy Fanelli', 'José Bénazéraf'], 'Añade un argumento en tu idioma\nA French crime potboiler starring Verner and Kalfon as rival gang leaders who clash over control of the narcotics trade.', '1h 15min', 'Le concerto de la peur', '1963')
# ('tt0055128', '6,5', ['Rafael Baledón'], ['Fernando Galiana', 'Rafael Baledón'], "Añade un argumento en tu idioma\nAfter fifteen years of being away, a woman returns with her husband to her aunt's hacienda in the Mexican countryside, without realizing that her relative is a sorceress who wants to use her to bring an evil witch back to life.", '1h 20min', 'La maldición de la Llorona', '1963')
# ('tt0055021', '5,3', ['Miguel Morayta'], ['Miguel Morayta'], 'Añade un argumento en tu idioma\nA doctor and his assistant hunt down a vampire named Count Frankenhausen, who is terrorizing the populace.', '1h 32min', 'La invasión de los vampiros', '1963')
# ('tt0056925', '6,4', ['Jesús Franco'], ['Charles Exbrayat', 'Jesús Franco', 'Gonzalo Sebastián de Erice'], 'Basada en la novela "Vous souvenez-vous de Paco".', '1h 40min', 'Rififí en la ciudad', '1963')
# ('tt0056923', '7,8', ['Stanley Donen'], ['Peter Stone', 'Marc Behm'], 'El romance y el suspense se suceden en París cuando una mujer es perseguida por varios hombres que quieren una fortuna que su marido asesinado había robado. ¿En quién puede confiar?', '1h 53min', 'Charada', '1963')
# ('tt0057332', '6,8', ['Moni Bhattacharjee'], ['Agha Jani Kashmiri'], 'Añade un argumento en tu idioma\nA notorious bandit continues to elude the authorities and strikes terror in the region.', '1h 35min', 'Mujhe Jeene Do', '1963')
# ('tt0057076', '7,3', ['Terence Young'], ['Richard Maibaum', 'Johanna Harwood', 'Ian Fleming'], 'James Bond cae voluntariamente en un complot de asesinato que involucra a una ingenua belleza rusa para recuperar un dispositivo de encriptación soviético que fue robado por SPECTRE.', '1h 55min', 'Desde Rusia con amor', '1963')
# ('tt0056459', '4,4', ['Gilbert Kay'], ['Stephen Longstreet', 'Charles Martin'], 'Añade un argumento en tu idioma\nWorld War II espionage in Lisbon with Allied safe-crackers cultivating a master spy and his wife so they can steal Japanese codes that are keys to Axis battle plans.', '1h 12min', 'The Secret Door', '1964')
# ('tt0055953', '5,0', ['León Klimovsky'], ['Antonio Fos'], 'Añade un argumento en tu idioma\nA girl who is engaged leaves the nightclub where she works. On her way home, she is the only witness of a horrible murder. Unfortunately for her, the killer has seen her. Since then, her life starts to turn into a real nightmare, because the killer is determined to eliminate her.', '1h 27min', 'Ella y el miedo', '1964')
# ('tt0057498', '4,7', ['Ernest Morris'], ['Ronald Liles', 'Reginald Hearne'], 'Añade un argumento en tu idioma\nAn aide at the American Embassy in London finds himself involved with both Scotland Yard and the French police over the kidnapping of the son of a Mafia boss who has spilled the beans back in the States.', '1h 10min', 'The Sicilians', '1964')
# ('tt0057082', '5,8', ['Julio Coll', 'Luis García'], ['Sidney W. Pink', 'Luis de los Arcos'], "Añade un argumento en tu idioma\nA married man has a brief affair, then goes back to his wife and children. His jilted mistress, believing that if he had no more family he'd come back to her, sets fire to his house, hoping to kill them. The man, unsuccessfully trying to rescue them, is horribly burned. After he undergoes an operation to reconstruct his face, he begins to plot his revenge against his ... Leer todo", '1h 30min', 'Fuego', '1964')
# ('tt0057938', '6,2', ['Ottavio Alessi', 'Paolo Heusch'], ['Bruno Corbucci', 'Giovanni Grimaldi', 'Ottavio Alessi'], 'Añade un argumento en tu idioma\nA pair of brothers, Baby Toto and Pietro, sons of different mothers, live stealing suitcases at the Termini Station in Rome. After a theft they discover that the stolen suitcase they got from an apparent sweet old lady actually contains a corpse.', '1h 50min', 'Che fine ha fatto Totò baby?', '1964')
# ('tt0057924', '5,7', ['Warren Kiefer', 'Luciano Ricci'], ['Paul Maslansky', 'Warren Kiefer', 'Fede Arnaud'], 'El Conde Drago invita a artistas a su castillo, pero lo que la gente no sabe es que Drago momifica animales y humanos.', '1h 31min', 'The Castle of the Living Dead', '1964')
# ('tt0057908', '5,7', ['Mario Mattoli'], ['Franco Enna', 'Roberto Gianviti', 'Mario Mattoli'], 'Añade un argumento en tu idioma\nLaura is the victim of a blackmail, asks for help to her childhood friends Renata, Marina and Giovanna in the meantime become a nun to collect the amount requested.', '1h 30min', 'Cadavere per signora', '1964')
# ('tt0058011', '6,0', ['Don Sharp'], ['Jimmy Sangster'], 'Un buque corsario averiado deserta de la Armada española y desembarca para realizar reparaciones cerca de un pueblo de la costa británica, aterrorizando a los habitantes locales.', '1h 26min', 'Los piratas del Diablo', '1964')
# ('tt0058049', '6,8', ['Erik Balling'], ['Erik Balling', 'Jens K. Holm'], 'Añade un argumento en tu idioma\nEntering a house to borrow the phone, a crime writer finds a murdered man and is knocked out. The police calls it suicide. A boy helps him investigate.', '1h 38min', 'Døden kommer til middag', '1964')
# ('tt0057148', '6,0', ['Rafael Baledón'], ['José María Fernández Unsáin', 'Ramón Obón'], 'Añade un argumento en tu idioma\nOdyssey of a man involved in a criminal activity, which leads him to his moral and material failure.', '1h 20min', 'Un hombre en la trampa', '1965')
# ('tt0057485', '5,3', ['Silvio Amadio'], ['Silvio Amadio', 'Giovanni Simonelli'], 'Añade un argumento en tu idioma\nIn this crime-thriller, Rome proves to be an unhappy destination for an American couple when the husband is kidnapped and his wife begins a desperate search for him.', '1h 44min', 'El secreto de Bill North', '1965')
# ('tt0057926', '6,2', ['Gordon Hessler'], ['Jay Bennett', 'Daniel Mainwaring'], "Añade un argumento en tu idioma\nAn astute businesswoman is completely devoted to her faithless husband, who must kill her to carry on with her pretty young niece. It turns out that the dead don't die so easily.", '1h 29min', 'Catacombs', '1965')
# ('tt0057948', '6,7', ['Ramón Obón'], ['Ramón Obón'], 'Añade un argumento en tu idioma\nA husband and his lover hatch a plan to murder his wife, and a woman is buried alive in a mausoleum.', '1h 40min', 'Cien gritos de terror', '1965')
# ('tt0057972', '6,6', ['José Luis Borau'], ['Juan Miguel Lamet', 'Rodrigo Rivero Balestia'], "Añade un argumento en tu idioma\nAndrés, son of a famous pianist, discovers the corpse of a tuner killed in his shop, located in the basement of his house. Then a suspect leaves, but in the fear of possible reprisals he doesn't tell anything to the police, only to his wife Laura. From that moment on, Andrés feels threatened and persecuted.", '1h 30min', 'Crimen de doble filo', '1965')
# ('tt0057857', '5,5', ['René Cardona'], ['René Cardona Jr.', 'René Cardona'], 'Añade un argumento en tu idioma\nMasked hero El enmascarado de oro faces a criminal that turns invisible.', '1h 25min', 'El asesino invisible', '1965')
# ('tt0058216', '6,0', ['Freddie Francis'], ['Jimmy Sangster'], 'Añade un argumento en tu idioma\nAfter a car accident in England, an American develops amnesia and tries to find his true identity, using various clues, but ends-up in the midst of a mysterious murder.', '1h 25min', 'Hysteria', '1965')
# ('tt0058610', '5,9', ['John Newland'], ['Joseph Calvelli', 'Clyde Ware'], 'Añade un argumento en tu idioma\nU.N.C.L.E. agents Napoleon Solo and Illya Kuryakin are sent to the Swiss Alps to find a secret nuclear weapon design but T.H.R.U.S.H. agents kidnap Solo and replace him with a look-alike double.', '1h 28min', 'Espia con mi cara', '1965')
# ('tt0058381', '5,5', ['Mario Camus'], ['Mario Camus', 'Carlos Saura'], 'Añade un argumento en tu idioma\nA salesman discovers that his wife has died under strange circumstances. Examining these circumstances it becomes obvious to him that they were mainly caused by himself.', '1h 35min', 'Muere una mujer', '1965')
# ('tt0058865', '5,5', ['Ernst Ritter von Theumer', 'Peter Jacob'], ['Kurt Vogelmann', 'Antonio del Amo'], 'Añade un argumento en tu idioma\nThe FBI sends agents to Jamaica to investigate arms smuggling to revolutionaries in Santo Domingo.', '1h 28min', '001, operación Caribe', '1965')
# ('tt0058359', '5,0', ['Agustín Navarro'], ['Pino Belli', 'Juan Miguel Lamet'], 'Añade un argumento en tu idioma', '1h 26min', 'El misterioso señor Van Eyck', '1966')
# ('tt0058878', '5,1', ['Manfred R. Köhler'], ['Manfred R. Köhler', 'Mario Siciliano'], "Añade un argumento en tu idioma\nSomething bad is being planned in Beirut, and it has something to do with a man called The Sheikh, who has only four fingers. It seems this isn't a lone incident. The Sheikh is also thought to be behind the assassination of several prominent scientists.", '1h 33min', 'Agente 505, muerte en Beirut', '1966')
# ('tt0060044', '6,5', ['Arthur Dreifuss'], ['Arthur Dreifuss', 'Dity Oorthuys', 'Leo Derksen'], "Añade un argumento en tu idioma\nPainter Peter Hartman is arrested at the scene of a murder. He soon turns out to have ties to the victim's young widow. As Inspector Stroomer begins to unravel the mystery, two very different sides of the story are presented to him. Now it is up to Stroomer to find enough photographic evidence to make out which version is the truth.", '1h 36min', '10.32', '1966')
# ('tt0059013', '7,1', ['Miguel M. Delgado'], ['Fernando Galiana'], 'Añade un argumento en tu idioma\nFederal agent infiltrates smuggling gang in seaport.', None, 'Cargamento prohibido', None)
# ('tt0059648', '5,5', ['Sergio Sollima'], ['Sergio Donati', 'Sergio Sollima', 'Antonio del Amo'], "Añade un argumento en tu idioma\nA veteran US Secret Service agent must thwart the covert conspiracy of an enemy spy network that threatens the world's safety.", '1h 42min', 'Consigna: Tánger 67', '1966')
# ('tt0059935', '5,7', ['Giorgio Stegani'], ['Remigio Del Grosso', 'José Luis Martínez Mollá', 'Giorgio Stegani'], 'Añade un argumento en tu idioma\nDoctor Morrow, a scientist who works for NASA, has mysteriously disappeared and the agent Lemmy Logan is in charge of the case.', '1h 32min', 'S077: Operación relámpago', '1966')
# ('tt0060052', '5,7', ['Angelo Dorigo'], ['Sergio Bazzini', 'Ernesto Gastaldi', 'Roberto Natale'], 'Añade un argumento en tu idioma\nAfter a rich mine worker dies in mine accident, his heirs gather in his house to hear the reading of the will.', '1h 16min', 'A... come assassino', '1966')
# ('tt0060295', '5,7', ['Raoul Lévy'], ['Robert Guenette', 'Raoul Lévy', 'Paul Thomas'], "Añade un argumento en tu idioma\nAn American scientist is sent by the CIA to East Germany to retrieve a secret microfilm from a Soviet scientist interested in defecting to the West but the Stasi secret police's surveillance complicates matters.", '1h 40min', 'El desertor', '1966')
# ('tt0056855', '5,5', ['José Díaz Morales'], ['José Díaz Morales', 'Rafael García Travesi', 'Fernando Osés'], 'Añade un argumento en tu idioma\nThe evil Baron Brakola wakes up from his sleep in order to take revenge and defeat the man in the silver mask.', '1h 17min', 'El barón Brákola', '1967')
# ('tt0060093', '5,2', ['Dariush Mehrjui'], ['Reza Fazeli', 'Dariush Mehrjui'], 'Añade un argumento en tu idioma\nA professor who found out a formula to make diamonds from oil is killed in Tehran and his nephew who is a spy is sent to Tehran by Interpol in order to find the formula.', '2h', 'Almaas 33', '1967')
# ('tt0060374', '5,0', ['Riccardo Freda'], ['Paul Kenny', 'Bertrand Tavernier', 'Christian Plume'], 'Añade un argumento en tu idioma\nSecret agent Francis Coplan is given the task of finding priceless artwork stolen by the Germans in 1943. The trail leads to Mexico, where Coplan challenges a secret organization in order to regain the paintings.', '1h 38min', 'Entre las redes', '1967')
# ('tt0060134', '5,7', ['Miguel M. Delgado'], ['Alfredo Ruanova'], 'Añade un argumento en tu idioma\nCops vs counterfeiter on a cruise ship from La Paz, Baja California to Mazatlán, Sinaloa.', None, 'El asesino se embarca', None)
# ('tt0060796', None, ['Pedro Martins'], ['Armando Cortez', 'Colette Dubois', 'Frank Gold'], 'Añade un argumento en tu idioma', '1h 30min', 'Operação Dinamite', '1967')
# ('tt0060944', '5,8', ['Claude Chabrol'], ['Claude Brulé', 'Derek Prouse', 'William Benjamin'], "Añade un argumento en tu idioma\nA champagne tycoon's (Furneaux) partner (Ronet) suspects his partner's gigolo husband (Perkins) of murders he's been framed for.", '1h 45min', 'Champaña por un asesino', '1967')
# ('tt0060326', '7,2', ['Francisco del Villar'], ['Emilio Carballido', 'Richard Wright', 'Francisco del Villar'], 'Añade un argumento en tu idioma\nRepressed middle-aged Catholic gets into a troublesome relationship with the prostitute next door and her little boy.', '1h 33min', 'Domingo salvaje', '1967')
# ('tt0060676', '5,2', ['Alberto Lattuada'], ['Ermanno Donati', 'Piero Regnoli', 'Jack Pulman'], 'Un agente secreto posee un anillo que lo hace invisible una vez cada 10 horas. Él persigue a una mente criminal malvada, pero, al mismo tiempo, debe evadir a un agente enemigo que también quiere el anillo.', '1h 45min', 'Sin rival', '1967')
# ('tt0060288', '6,2', ['Ralph Thomas'], ['Jimmy Sangster', 'David D. Osborn', 'Liz Charles-Williams'], 'El agente británico Bulldog Drummond es asignado para detener a un maestro criminal que usa mujeres hermosas para cometer sus asesinatos.', '1h 41min', 'Más peligrosas que los hombres', '1967')
# ('tt0057858', '5,2', ['José Díaz Morales'], ['Rafael García Travesi', 'Fernando Osés'], 'Añade un argumento en tu idioma\nSanto must battle an evil witch and the demons and evil spirits she brings up from Hell.', '1h 16min', 'Atacan las brujas', '1968')
# ('tt0060265', '5,2', ['Albert Zugsmith'], ['Vivian Connell', 'Albert Zugsmith'], 'Añade un argumento en tu idioma\nAn unorthodox doctor makes a house call to the Acapulco abode of a mushroom addict.', '1h 35min', 'The Chinese Room', '1968')
# ('tt0060226', '5,0', ['Federico Curiel'], ['Adolfo Torres Portillo', 'Luis Enrique Vergara'], "Añade un argumento en tu idioma\nArácnea's residents have been desperately searching for a source of food to save the life of their queen. Earth is chosen, since human brains are apparently like health food for alien spiders.", '1h 25min', 'Arañas infernales', '1968')
# ('tt0061952', '5,6', ['Fernando Cerchio', 'Nando Cicero'], ['Eduardo Manzanos', 'Luciano Secchi', 'Roberto Raviola'], 'Añade un argumento en tu idioma\nWhereas the first film concerned a string of diamond robberies , this involves the search for a couple of missing paintings by world-renowned artists - the map of the location in question is hidden inside four identical statues of a Buddha.', '1h 32min', 'Los cuatro budas de Kriminal', '1968')
# ('tt0061946', '4,8', ['Richard Rush'], ['Leighton J. Peatman', 'Robert S. Weekley'], 'Añade un argumento en tu idioma\nA wheelchair-bound mad scientist plots to revive the Third Reich. Secret agent Dick Dagger is assigned to stop him.', '1h 26min', 'A Man Called Dagger', '1968')
# ('tt0061864', '5,6', ['Primo Zeglio'], ['Mario Amendola', 'José Mallorquí', 'Primo Zeglio'], 'Un joven regresa a su pueblo natal diez años después de matar al asesino de sus padres. Una vez allí, se le pide que ayude al sheriff.', '1h 42min', 'Winchester: Uno entre mil', '1968')
# ('tt0061054', '6,5', ['Giorgos Papakostas'], ['Giorgos Papakostas'], "Añade un argumento en tu idioma\nMaro is being raped by her sister's husband so she leaves her house ashamed and she gets deeper into problems. One day she meets a good doctor and while she thinks she grabs happiness, secrets come up and people from their past reappear.", '1h 29min', 'To syrtaki tis amartias', '1966')
# ('tt0061340', '4,4', ['Enrique López Eguiluz'], ['Juan Logar'], "Añade un argumento en tu idioma\nA surgeon's girlfriend dies in the operating room and begins to kill medical surgery students, amputating the hands of his victims so that they cannot harm his beloved, whom he still believes alive.", '1h 25min', 'Agonizando en el crimen', '1968')
# ('tt0061459', '5,2', ['Chano Urueta'], ['Antonio Orellana', 'Fernando Osés'], 'Añade un argumento en tu idioma\nA wrestling hero helps the police in their battle against a mad doctor and his army of female zombies.', '1h 25min', 'Blue Demon contra cerebros infernales', '1968')
# ('tt0058968', '5,9', ['Carl K. Hittleman'], ['Carl K. Hittleman'], 'Añade un argumento en tu idioma\nA visitor to the Everglades swamps in Florida encounters and falls in love with an uneducated girl. But he finds competition for her affections from the unlikely and mysterious A. Beauregard Lincoln. He also discovers danger from nature in the form of vicious alligators and from the mystical in the form of a voodoo witch doctor.', '1h 8min', 'Big Daddy', '1969')
# ('tt0061453', '4,9', ['Jesús Franco'], ['Jesús Franco', 'Gert Günther Hoffmann', 'Karl Heinz Mannchen'], 'Añade un argumento en tu idioma\n"Red Lips" are two female detectives trying to find missing models and dancers. A pop artist called Klaus Thriller and his werewolf-like assistant, Morpho, are the main suspects for the murderers.', '1h 32min', 'El caso de las dos bellezas', '1969')
# ('tt0061432', '4,3', ['Jesús Franco'], ['Jesús Franco', 'Luis Revenga', 'Gert Günther Hoffmann'], 'Añade un argumento en tu idioma\nKISS ME, MONSTER finds The Red Lips moonlighting on a striptease world tour - but no sooner do they hit the stage than the girls are up to their pasties in stiffs, Satanists and Sapphic sadists, all after a secret formula for human clones!', '1h 27min', 'Bésame monstruo', '1969')
# ('tt0061580', '6,7', ['Gonzalo Suárez'], ['Gonzalo Suárez'], "Añade un argumento en tu idioma\nDitirambo is an atypical hero who never smiles, always tells the truth and carries out relentlessly as many missions entrust him. A writer's widow instructs him to locate her husband's former mistress for the purpose of revenge. Thus, the tragicomic events that lead to an unpredictable end are unleashed.", '1h 43min', 'Ditirambo', '1969')
# ('tt0062255', '5,0', ['Jaime Salvador'], ['Ramón Obón'], 'Añade un argumento en tu idioma\nA mad scientist teams with an evil, disfigured woman to kidnap and operate on young women to make her look beautiful again.', '1h 25min', 'La señora Muerte', '1969')
# ('tt0062438', '5,5', ['Javier Setó'], ['Santiago Moncada', 'Javier Setó', 'Gianfranco Clerici'], "Añade un argumento en tu idioma\nA scheming blonde plots to steal her husband's money, not by killing him, but by driving him to the brink of insanity so that, once he's institutionalized, she and his twin brother (who she's having an affair with ] can run his estate and have all his money.", '1h 31min', 'Viaje al vacío', '1969')
# ('tt0062769', '6,7', ['Michel Deville'], ['Nina Companeez', 'Michel Deville'], 'Añade un argumento en tu idioma\nA journalist meets a pretty, young woman in Biarritz and they fall in love with each other. Once they have returned to Paris the woman disappears mysteriously.', '1h 42min', 'Bye bye, Barbara', '1969')
# ('tt0062836', '6,2', ['Vicente Aranda'], ['Vicente Aranda', 'Antonio Rabinad', 'Gonzalo Suárez'], 'Añade un argumento en tu idioma\nA grumpy publisher receives a parcel containing a hand that may or may not be fake. A woman is following him. Someone from his past? Reality and fantasy begin to intermingle.', '1h 48min', 'Las crueles', '1969')
# ('tt0061494', '4,0', ['Santos Alcocer', 'Edward Mann'], ['John Melson', 'Edward Mann', 'José Luis Bayonas'], 'Añade un argumento en tu idioma\nA blind sculptor works on his magnum opus, unaware that the skeletons that he has been using for armatures are the remains of the victims of his evil wife and that he is her next target.', '1h 37min', 'El coleccionista de cadáveres', '1968')
# ('tt0063309', '6,1', ['Gilberto Martínez Solares'], ['Juan García', 'Gilberto Martínez Solares', 'Ramón Obón'], 'Añade un argumento en tu idioma', '1h 25min', 'Misión cumplida', '1970')
# ('tt0063696', '5,6', ['R.G. Springsteen'], ['Charles A. Wallace'], 'Añade un argumento en tu idioma\nVietnam war hero, accused of murdering his brother, recruits his socialite girlfriend to hunt for the real killer.', '1h 39min', 'Tiger by the Tail', '1970')
# ('tt0064126', '5,0', ['Pierre Koralnik'], ['F.S. Gilbert', 'Franz-André Burguet', 'Pierre Koralnik'], 'Añade un argumento en tu idioma\nSerge Morgan is a killer working for the American Mafia. After performing a contract in New York for his employers, he takes the plane back to Paris and, during the flight, he gets to know Jane, the rich daughter of an ambassador. Once in Orly Airport he gets seriously wounded by the men of French drug kingpin Henri Emery. He manages to escape them though and takes re... Leer todo', '1h 36min', 'Cannabis', '1970')
# ('tt0063552', '5,5', ['Donald Wolfe'], ['Donald Wolfe'], 'Añade un argumento en tu idioma\nAn aging actress living in her Hollywood mansion with a retinue of elderly servants employs a new, mentally disturbed, personal assistant who schemes to take over the large estate.', '1h 31min', 'Intruso salvaje', '1970')
# ('tt0064106', '7,3', ['Claude Chabrol'], ['Claude Chabrol'], 'Una amistad entre un carnicero de clase trabajadora y un maestro de escuela reprimido coincide con una serie espeluznante de asesinatos similares a los de Jack el Destripador en una ciudad francesa de las provincias.', '1h 33min', 'El carnicero', '1970')
# ('tt0064177', '7,1', ['Joseph Sargent'], ['James Bridges', 'D.F. Jones'], 'Pensando que así se evitará la guerra, el gobierno estadounidense concede al superordenador un control total e impenetrable sobre el lanzamiento de misiles nucleares. Pero lo que el ordenador hace con la potencia es inimaginable.', '1h 40min', 'Colossus: el proyecto prohibido', '1970')
# ('tt0064413', '4,4', ['Julio Diamante'], ['Julio Diamante'], "Añade un argumento en tu idioma\nAn important industrialist suffers a neurosis. In a violent argument he strikes his wife and apparently kills her. Then the body disappears. Criminal melodrama inspired by a similar situation set out by Henri Georges Clouzot in 'Les diaboliques'.", '1h 34min', 'Helena y Fernanda', '1970')
# ('tt0064225', '6,9', ['José Giovanni'], ['Joseph Harrington', 'José Giovanni'], 'Añade un argumento en tu idioma\nPolice inspector Léonetti, a tough, efficient policeman, has been sent to a second-rate police station after being reprimanded. There he is given a partner, young and beautiful Jeanne Dumas. The duo are soon assigned a very difficult mission: to find a man whose evidence is instrumental in convicting a murderer. They start searching throughout Paris...', '1h 45min', 'Último domicilio conocido', '1970')
# ('tt0064630', '3,9', ['Jean-Pierre Decourt'], ['Jean-Pierre Decourt', 'Raymond Jacquet', 'Marcel Jullian'], 'Añade un argumento en tu idioma\nThriller Melodrama features the adventures of Marc St Jacques (known as Doctor Caribbean) and his friend Jeff, played respectively by Louis Velle and Jess Hahn.', '1h 35min', 'Docteur Caraïbes', '1970')
# ('tt0060939', '5,5', ['René Cardona'], ['René Cardona', 'Adolfo Torres Portillo'], 'Añade un argumento en tu idioma\nFamed wrestler/secret agent El Santo must venture deep into the Amazon jungle to rescue a girl who is set to be sacrificed under the full moon by the Jibaro indians.', '1h 20min', 'Santo contra los cazadores de cabezas', '1971')
# ('tt0063244', '4,3', ['Doris Wishman'], ['Judy J. Kushner', 'Lawrence Perrin'], 'Un jugador compulsivo juega con su propia hija adolescente. Ella se convierte en la esclava sexual de su oponente.', '1h 16min', 'Love Toy', '1971')
# ('tt0064451', '7,5', ['King Hu'], ['Songling Pu', 'King Hu'], 'Una dama fugitiva que huye de los funcionarios corruptos del gobierno se alía con un pintor poco ambicioso y unos hábiles monjes budistas.', '3h 20min', 'Un toque de zen', '1971')
# ('tt0065735', '5,7', ['Piero Sciumè'], ['Tiziano Cortini', 'Ricardo Ferrer', 'Julio Salvador'], 'Añade un argumento en tu idioma\nA couple of blackmailers abduct a child from a married couple as a means of coercing the banker husband into funneling a huge sum of cash in their direction.', '1h 25min', 'Las fotos de una mujer decente', '1971')
# ('tt0065770', '6,4', ['Juan Ibáñez'], ['Juan Ibáñez', 'Arturo Rosenblueth'], 'Añade un argumento en tu idioma\nDuring the Mexican Revolution, a hardened and rich lady landowner is overtaken by the violence of the times. Losing her land and house, she falls in love with a revolutionary leader that is killed by a sadistic and corrupt federal officer. She takes the revolutionary flag and leads a rampage of violence and destruction.', '1h 40min', 'La generala', '1971')
# ('tt0065761', '6,6', ['Dario Argento'], ['Dario Argento', 'Luigi Cozzi', 'Dardano Sacchetti'], 'Un no vidente y un reportero de un periódico intentan resolver una serie de asesinatos relacionados con el proyecto de investigación de alto secreto de una compañía farmacéutica y se convierten en el objetivo del asesino.', '1h 52min', 'El gato de 9 colas', '1971')
# ('tt0065619', '4,9', ['Stellan Olsson'], ['Stellan Olsson'], 'Añade un argumento en tu idioma\nA terrifying drama about what might happen in a disaster situation. An airplane loaded with bacteriological weapons crashes in the south of Sweden, causing an epidemic.', '1h 48min', 'Deadline', '1971')
# ('tt0064143', '4,3', ['Luis Marquina'], ['Luis Marquina', 'Juan Tébar'], "Añade un argumento en tu idioma\nAt the Grand Hotel in Miami, Carla falls into the arms of her husband, the eminent Dr. Warren, and confesses to having seen Nick, the man he killed in New York, at the airport - Carla was a nightclub dancer. New York and Nick's lover. Later, Warren accidentally discovered the real reason why Carla agreed to marry him: a combination with Nick, who plot his death and th... Leer todo", '1h 30min', 'Cerco de terror', '1970')
# ('tt0065424', '5,0', ['Curtis Hanson'], ['Curtis Hanson'], 'Un maníaco psicótico que literalmente "ama" a las mujeres hasta la muerte.', '1h 25min', 'Sweet Kill', '1972')
# ('tt0066192', '7,2', ['Jacques Rivette'], ['Jacques Rivette', 'Suzanne Schiffman'], 'Añade un argumento en tu idioma\nA shorter version of Out 1, noli me tangere (1971), however some of the omitted scenes of the long version are included.', '4h 13min', 'Out 1: Spectre', '1972')
# ('tt0066756', '6,6', ['Julio Buchs'], ['Julio Buchs', 'Domenico Comanducci', 'Federico De Urrutia'], "Añade un argumento en tu idioma\nJosé, a young mechanic, arrives in Madrid to make it big. After being conned he loses his savings, and is taken in by Elisa, a photographer. She introduces him to Pablo and Laura. Laura makes him an offer he can't refuse and then his troubles really begin.", '1h 31min', 'Alta tensión', '1972')
# ('tt0066939', '6,7', ['Joaquín Luis Romero Marchent'], ['Joaquín Luis Romero Marchent', 'Santiago Moncada'], 'Los bandidos atacan a un carro lleno de convictos, y solo un sargento, su hija y siete prisioneros sádicos sobreviven. El sargento debe llevar a sus prisioneros a su destino mientras se desarrolla una red de mentiras, codicia y traición.', '1h 30min', 'Condenados a vivir', '1972')
# ('tt0067015', '6,0', ['Roberto Gavaldón'], ['Hugo Argüelles', 'Roberto Gavaldón'], 'Añade un argumento en tu idioma', '1h 50min', 'Doña Macabra', '1972')
# ('tt0066982', '5,3', ['Peter Sykes'], ['Christopher Wicking', 'Frank Godwin'], 'Añade un argumento en tu idioma\nA physician discovers that two children are being kept virtually imprisoned in their house by their father. He investigates, and discovers a web of sex, incest, and Satanic possession.', '1h 29min', 'Los demonios de la mente', '1972')
# ('tt0067052', '6,0', ['Sidney Gilliat'], ['Agatha Christie', 'Sidney Gilliat'], 'Un joven inglés de clase trabajadora se casa con una afable heredera americana, pero su felicidad conyugal se ve pronto interrumpida cuando empiezan a construir una casa en un terreno supuestamente maldito.', '1h 39min', 'La noche sin fin', '1972')
# ('tt0060951', '4,6', ['Carl Monson', 'Dwayne Avery', 'Bethel Buckalew'], ['Eric Norden'], 'Añade un argumento en tu idioma\nTwo Los Angeles detectives are assigned to track down and arrest a brutal rapist-murderer terrorizing the city. Their job is complicated by the fact that the killer is able to avoid capture because he can pose as a woman.', '1h 31min', 'A Scream in the Streets', '1973')
# ('tt0066156', '4,0', ['Robert Allen Schnitzer'], ['Robert Allen Schnitzer', 'Larry Beinhart', 'Louis Pastore'], 'Nueva York, fin de los años 60, un grupo de estudiantes planea colocar bombas en oficinas que hacen negocios con países suramericanos gobernados por dictadores. Para ello se ponen en contacto con un terrorista experto en explosivos.', '1h 20min', 'No hay lugar para esconderse', '1973')
# ('tt0065574', '4,5', ['John Hayes'], ['Edward M. Wingfield'], 'Añade un argumento en tu idioma\nThe Browns take their Catholic high school students on a picnic. As one student sneaks to her boyfriend, two others seduce escaped convicts who rape the fourth. Mrs. Brown and her husband fall victims to their prudence.', '1h 15min', 'Bust Out', '1973')
# ('tt0068236', '5,8', ['Juan Luis Buñuel'], ['Juan Luis Buñuel', 'Pierre-Jean Maintigneux'], 'Añade un argumento en tu idioma\nA married couple purchases an abandoned house in the countryside. Soon they witness strange apparitions and events. Their son and their prepubescent daughter are haunted by a poltergeist.', '1h 30min', 'Cita con la muerte alegre', '1973')
# ('tt0068547', '4,4', ['José María Elorrieta'], ['José María Elorrieta'], 'Añade un argumento en tu idioma\nA twisted sleazebag stalks and strangles gorgeous women in this Spanish terror classic.', '1h 21min', 'El espectro del terror', '1973')
# ('tt0069270', '6,9', ['Claude Pinoteau'], ['Jean-Loup Dabadie', 'Claude Pinoteau', 'Francis Ryck'], 'Añade un argumento en tu idioma\nWho is Anton Haliakov, who has just been abducted by the M.I.5 in London? A Soviet scientist apparently. But sixteen years before the man had another identity, Clément Tibère, and another nationality, French. So what led him to become Russian and to change identity? And why are the British secret services interested in him?', '1h 35min', 'El silencioso', '1973')
# ('tt0068488', '6,2', ['Dino Risi'], ['Ruggero Maccari', 'Dino Risi', 'Bernardino Zapponi'], 'Añade un argumento en tu idioma\nIn 1970s Italy, an industrialist and his mistress are taken hostage by three left-wing extremists who robbed a bank but the police and a media circus follow them closely on a cross-country car chase.', '1h 47min', 'Sábado inesperado', '1973')
# ('tt0068724', '6,2', ['Philippe Labro'], ['Philippe Labro', 'Jacques Lanzmann'], 'Añade un argumento en tu idioma\nA heir of media empire investigates who the enemy of his family is.', '1h 52min', 'El heredero', '1973')
# ('tt0068382', '6,6', ['Jorge Fons'], ['Ralph Barby', 'Arturo Ripstein'], 'Añade un argumento en tu idioma\nA mayor offers five thousand dollars to the gunman Hunter to finish off Kotin without killing any of his gang.', '1h 30min', 'Cinco mil dolares de recompensa', '1974')
# ('tt0069041', '6,0', ['Carlos Aured'], ['Paul Naschy', 'Carlos Aured'], 'Un ex convicto, atormentado por sueños en los que estrangula mujeres, es contratado como cuidador en una finca propiedad de tres hermanas muy extrañas.', '1h 29min', 'Los ojos azules de la muñeca rota', '1974')
# ('tt0068457', '6,6', ['Bob Clark'], ['Alan Ormsby'], 'Añade un argumento en tu idioma\nA young soldier killed in the Vietnam War inexplicably shows up at his family home on the night of his death.', '1h 28min', 'Crimen en la noche', '1974')
# ('tt0069243', '5,7', ['Georges Lautner'], ['Richard Matheson', 'Georges Lautner'], 'Añade un argumento en tu idioma\nOn a beach in Nice, François meets the mysterious Peggy and falls in love with her. Following her to a villa, he meets Marc, a lawyer who has a strange relationship with the girl. Marc tells François that Peggy is a drug addict: she kills men who approach her.', '1h 45min', 'Los senos de hielo', '1974')
# ('tt0069435', '4,2', ['Maria Virginia Onorato'], ['Maria Virginia Onorato'], 'Añade un argumento en tu idioma', '1h 55min', "L'ultimo uomo di Sara", '1974')
# ('tt0069022', '4,9', ['David Lowell Rich'], ['Paul C. Ross', 'Antonio Santean'], 'Añade un argumento en tu idioma\nThree adventurers--at times competing with each other, at other times allied with each other--search South Korea for a magical sword that is supposed to imbue its owner with wealth and power.', '1h 24min', 'Al noreste de Seúl', '1974')
# ('tt0069241', '5,3', ['Karl Heinz Zeitler'], ['Karl Heinz Zeitler', 'Joseph Amiel', 'Ricardo Ferrer'], 'Añade un argumento en tu idioma\nA sadistic killer pursues a beautiful woman in a twisted "hunt" so he can have her as his trophy.', '1h 22min', 'Una secretaria para matar', '1972')
# ('tt0068904', '5,4', ['Feng Huang'], ['Feng Huang', 'Kuang Ni'], 'Añade un argumento en tu idioma\nStoner, an Australian cop, has been investigating the spread of a mysterious addictive drug that acts like an aphrodisiac and a hallucenogen on anyone who takes it. When his own sister falls under its influence, he travels to Hong Kong to hunt down the man behind the drug trade, the evil billionaire Mr. Chin. At the same time, a Taiwanese officer has also been sent to... Leer todo', '1h 47min', 'Stoner: Agente muy especial', '1974')
# ('tt0069909', '7,5', ['Sergiu Nicolaescu'], ['Eugen Burada', 'Vintilä Corbul', 'Mircea Gandila'], 'Añade un argumento en tu idioma\nThe Iron Guard, also known as Legion of Archangel Michael, was a Romanian nationalist and patriotic movement of extreme right; as such, after it rose to power, it supported Nazi Germany and started a fierce campaign of retaliation against its political enemies. As such, in the night of November 26-27, 1940, the Death Teams executed forty political prisoners in the Jil... Leer todo', '1h 54min', 'Un comisar acuzã', '1974')
# ('tt0069735', '5,7', ['Jesús García de Dueñas'], ['Jesús Torbado', 'Jesús García de Dueñas'], 'Añade un argumento en tu idioma\nA psychologically damaged young man murders young women who sexually excite him.', '1h 21min', 'El asesino no está solo', '1975')
# ('tt0069930', '5,3', ['Jesús Franco'], ['Jesús Franco', 'Elisabeth Ledu de Nesle'], 'Añade un argumento en tu idioma\nTwo wealthy aristocrats lure a virginal girl to a Spanish island for a night of sex, death and cannibalism.', '1h 27min', 'La condesa perversa', '1975')
# ('tt0070031', '5,8', ['Manuel Mur Oti'], ['Emilio Martínez Lázaro', 'Rafael Moreno Alba', 'Manuel Mur Oti'], 'Añade un argumento en tu idioma\nA beautiful young woman sets her sights on an aging millionaire. She seduces him, and moves into his mansion with him. She soon tires of him, though, and after she gets rid of him, she goes after his son', '1h 35min', 'La encadenada', '1975')
# ('tt0070312', '5,7', ['León Klimovsky'], ['Ricardo Muñoz Suay', 'Paul Naschy'], 'Un asesino está limpiando las calles de Milán asesinando a quienes considera desviados. Sobre cada cadáver deja una libélula ornamental empapada en la sangre de la víctima.', '1h 25min', 'Una libélula para cada muerto', '1975')
# ('tt0070834', '4,6', ['Earl Barton'], ['Earl Barton'], 'Una profesora y sus alumnas se van de excursión al desierto. El autobús sufre una avería y se ven aterrorizadas por una banda de motoristas psicópatas.', '1h 31min', 'Trip with the Teacher', '1975')
# ('tt0070636', '6,1', ['Gilberto Martínez Solares'], ['Jorge Barragán', 'Adolfo Martínez Solares', 'Gilberto Martínez Solares'], 'Añade un argumento en tu idioma\nA young nun is tempted by visions of forbidden sexual fantasies to cross over to Satan.', '1h 29min', 'Satanico Pandemonium: La Sexorcista', '1975')
# ('tt0070556', '5,4', ['David Worth', 'Richard Robinson'], ['B.W. Sandefur', 'Jean Genet'], "Añade un argumento en tu idioma\nA wrong turn on jazz singer Elizabeth Wetherly's road trip in the American South results in her car breaking down near an isolated lodge run by faded starlet Bertha Collins and her son - young, homicidal Elvis Presley impersonator Eddie.", '1h 32min', 'Matanza en el condado de Cuello Rojo', '1975')
# ('tt0071164', '5,9', ['Miguel Madrid'], ['Miguel Madrid'], 'Un estudiante de medicina está obsesionado con las muñecas, hasta que su mente degenera convirtiéndolo en un psicópata que mata a mujeres.', '1h 38min', 'El asesino de muñecas', '1975')
# ('tt0071099', '5,0', ['Tulio Demicheli'], ['Santiago Moncada'], 'Añade un argumento en tu idioma\nUn compositor español obsesivamente escribe canciones para una modelo que solo ha visto en fotografías, sin imaginarse que ella es vecina de el y su novia.', '1h 34min', 'Juego sucio en Panamá', '1975')
# ('tt0071297', '6,1', ['Patrice Chéreau'], ['James Hadley Chase', 'Jean-Claude Carrière', 'Patrice Chéreau'], 'Una joven perturbada se mantiene prisionera en un castillo, por su tía, debido a su dinero.', '1h 50min', 'La carne de la orquídea', '1975')
# ('tt0052259', '7,4', ['Alejandro Galindo'], ['Pancho Córdova', 'Rafael García Travesi', 'Raúl de Anda'], 'Añade un argumento en tu idioma', '1h 10min', 'El supermacho', '1960')
# ('tt0052721', '7,5', ['Martin Fric'], ['Jan Drda', 'Martin Fric'], 'Añade un argumento en tu idioma\nCuba Drobbyan (Jiri Sovak) is a poor cavalier who has a good wife (Bela Jurdova) and eleven children. When it comes to the twelfth, Cuba decides to go into the world and get a good godfather for him. Meanwhile, the old man meets Bohas Zahorsky, but he does not want to be a godfather, because he is not equally equitable to all people, he rejects the devil (Otakar Brous... Leer todo', '1h 20min', 'Darbuján a Pandrhola', '1960')
# ('tt0053056', '6,4', ['Jaroslav Mach'], ['J.Z. Novak'], 'Añade un argumento en tu idioma\nFunny tale for the youngest viewers about a beautiful princess and a clever hunter servant who outwitted the king.', '51min', 'Medved a strasidla', '1960')
# ...
# ('tt0057404', '6,0', ['Ion Popescu-Gopo'], ['Ion Popescu-Gopo'], 'Añade un argumento en tu idioma\nAn aspiring astronaut prepares his ship for take-off, plugs in a razor and causes a blackout. In the deep darkness the boy imagines himself meeting the literary characters who have enthralled readers past with their stories of space travel.', '1h 14min', 'Pasi spre luna', '1964')
# ('tt0057897', '6,3', ['Harry Keller'], ['Oscar Brodney', 'Thomas Anstey Guthrie'], "Añade un argumento en tu idioma\nAn architect buys an antique brass bottle that contains an ancient genie who's determined to fulfill his new master's every wish.", '1h 29min', 'Mi novio está loco, loco', '1964')
# ('tt0057894', '7,2', ['Karel Zeman'], ['Pavel Jurácek', 'Radovan Krátky', 'Milos Macourek'], "Añade un argumento en tu idioma\nKarel Zeman's brilliant animation, cowritten with Jurácek: ironic, surreal, following the adventures of a plowboy and a mercenary to the battlefields of the Thirty Years War.", '1h 22min', 'Crónica de un bufón', '1964')
# ('tt0057865', None, ['Ram Dayal'], ['Mumtaz Askari', 'Vijaya Choudhury', 'Jeevan Dhar'], "Añade un argumento en tu idioma\nWhen a child is crushed under the evil prime minster's chariot, the father of the deceased child kidnaps and raises the prime minster's child as his own to become a rebel.", None, 'Baghi', None)
# ('tt0054240', '3,0', ['Stephen C. Apostolof'], ['Edward D. Wood Jr.'], 'Añade un argumento en tu idioma\nA couple driving to a cemetery looking for inspiration for a horror story encounters the dancing dead.', '1h 32min', 'La orgía de los muertos', '1965')
# ('tt0058662', '6,4', ['Gilberto Martínez Solares'], ['Gilberto Martínez Solares', 'Germán Valdés'], 'Añade un argumento en tu idioma\nTin-Tan Cruz, a taxi driver who is accused of stealing money from tourists, escapes to an island where men are prisoners of god Mio Mao and women are ruled by wicked king Soleto.', '1h 30min', 'Tintansón CruZoe', '1965')
# ('tt0058374', '6,3', ['Aleksandr Rou'], ['Nikolay Erdman', 'Mikhail Volpin'], 'Añade un argumento en tu idioma\nA fairy-tale about a conceited young man and a young woman with a tyrannical step-mother, who must overcome magical trials in order to be together.', '1h 24min', 'Morozko', '1965')
# ('tt0058423', '7,2', ['Erast Garin', 'Khesya Lokshina'], ['Erast Garin', 'Khesya Lokshina', 'Evgeniy Shvarts'], 'Añade un argumento en tu idioma\nHow difficult it is to be a real person. This was fully felt "in his own skin" by the bear, whom the wizard turned into a beautiful young man. The most terrible was the condition set by the magician.', '1h 39min', 'Obyknovennoe chudo', '1965')
# ('tt0059172', '5,5', ['Vicente Aranda'], ['Vicente Aranda', 'Gonzalo Suárez'], 'Añade un argumento en tu idioma\nThe inhabitants of a strange desert Barcelona are gradually leaving the city in a panic group. The victims of a serial killers seem to feel strangely attracted by their executioners. Only Gim, an attractive blonde advertising model, decides to face her destiny.', '1h 24min', 'Fata Morgana', '1966')
# ('tt0059557', '6,4', ['Daniel Mann'], ['Hal Fimberg', 'Ben Starr'], 'Científicos usan el ecoterrorismo para imponer su voluntad en el mundo al afectar los extremos en el clima, el Jefe de Inteligencia Cramden llama al agente superior Derek Flint.', '1h 48min', 'Flint, agente secreto', '1966')
# ('tt0059604', '4,5', ['Alfredo B. Crevenna'], ['Alfredo Ruanova', 'Emilio Gómez Muriel'], 'Añade un argumento en tu idioma\nA group of sexy space vixens fly down to Earth, set up shop at a carnival, and kidnap some earthlings for use in their scheme to conquer this planet.', '1h 26min', 'El planeta de las mujeres invasoras', '1966')
# ('tt0059495', '6,4', ['George Harrison Marks'], ['Terry Maher', 'George Harrison Marks', 'Jim McDonald'], 'Añade un argumento en tu idioma\nWork of popular nude photographer.', '1h 24min', 'The Naked World of Harrison Marks', '1966')
# ('tt0059032', '3,5', ['Rossano Brazzi'], ['Paul Tripp', 'Rossano Brazzi'], 'Añade un argumento en tu idioma\nSanta has to get a job as Santa to earn money to pay his overdue rent bill', '1h 34min', 'Il Natale che quasi non fu', '1966')
# ('tt0059222', '4,3', ['Alfredo B. Crevenna'], ['Emilio Gómez Muriel', 'Alfredo Ruanova'], "Añade un argumento en tu idioma\nDaniel Wolf, scientist with a brand new rocket ship and a girlfriend/secretary is sent to 'the planet of the eternal night' to fight the guy who has threatened earth.", '1h 28min', 'Gigantes planetarios', '1966')
# ('tt0060104', '6,7', ['Lekh Tandon'], ['Arjun Dev Rashk', 'Balbir Singh', 'Omkar Sahib'], 'Añade un argumento en tu idioma\nA victory over neighboring state Vaishai has always eluded Magadh Samrat Ajaatshatru despite being winning and taking control over all neighboring states. He attacks Vaishali only get defeated again. Wounded, lost and on the run, Ajaatshatru dons the guise of a Vaishali soldier and takes shelter with a woman named Amrapali and they fall in love with each other. Ajaats... Leer todo', '1h 59min', 'Amrapali', '1966')
# ('tt0059010', '6,4', ['Gilberto Martínez Solares'], ['Roberto Gómez Bolaños'], 'Añade un argumento en tu idioma\nA group of people, including Capulina and Viruta, head towards the city by train. A heavy storm interrupts their journey and now they must take a haunted path to reach they city. (English Subtitled)', '1h 25min', 'El camino de los espantos', '1967')
# ('tt0060718', '6,6', ['Jan Nemec'], ['Ester Krumbachová', 'Jan Nemec'], 'Añade un argumento en tu idioma\nA series of loosely-connected shorts comprised of three tales representing different aspects of love: temptation, dreams, and adventure.', '1h 11min', 'Mucedníci lásky', '1967')
# ('tt0060938', '5,2', ['Alfredo B. Crevenna'], ['Rafael García Travesi'], 'El luchador enmascarado lucha contra los marcianos con la intención de apoderarse de la Tierra.', '1h 32min', 'Santo Versus la invasión de los marcianos', '1967')
# ('tt0060966', '7,0', ['Joseph W. Sarno'], ['Joseph W. Sarno'], 'Añade un argumento en tu idioma\nThe Cocoa Poodle bar is the central meeting place for the denizens of a bohemian suburban area. Janet, a rather colorless model, is jealous of her artist/mentor Tanya, who attracts the attention of all the local guys. An exotic card-reader offers her a pair of earrings which will give her power over others. She soon becomes the center of attention, but commits a fatal... Leer todo', '1h 13min', 'The Sex Cycle', '1967')
# ('tt0060400', '6,7', ['André Hunebelle'], ['Pierre Souvestre', 'Marcel Allain', 'Jean Halain'], 'Los famosos y desafortunados cazadores de Fantomas de Francia viajan a la extraña Escocia en un último intento de llevar ante la justicia a un insolente criminal.', '1h 40min', 'Fantomas contra Scotland Yard', '1967')
# ('tt0061790', None, ['Sang Siu'], ['Sang Siu'], 'Añade un argumento en tu idioma', '1h 38min', 'Sheng huo xiong feng da po huo lian zhen', '1967')
# ('tt0060108', '6,5', ['Francisco del Villar'], ['Fernando Galiana', 'Adolfo Torres Portillo'], 'Añade un argumento en tu idioma', '1h 35min', 'Los ángeles de Puebla', '1968')
# ('tt0060379', '7,4', ['Servando González'], ['Jorge Durán Chávez', 'Rafael García Travesi', 'Servando González'], "Añade un argumento en tu idioma\nA woman who is about to die calls the town's priest and hands him a scapulary, saying that she knows of its great powers. Anybody who does not believe in them will end up dead.", '1h 25min', 'El escapulario', '1968')
# ('tt0061561', '5,0', ['Doris Wishman'], ['Doris Wishman'], "Añade un argumento en tu idioma\nZeb finds a doll and a ring in a garbage can. Then, he sees Ann going to work with her friend Babs. He thinks she looks like the doll. When he gets home, he caresses the doll... Ann feels it! When Zeb finds out about Ann's fiance Tom, he really gets mad, burns the doll, and beats it up, which makes Ann think she's losing her mind.", '1h 15min', 'Indecent Desires', '1968')
# ('tt0061643', '6,7', ['Alejandro Jodorowsky'], ['Fernando Arrabal', 'Alejandro Jodorowsky'], "Añade un argumento en tu idioma\nFando and his partially-paralyzed lover Lis search for the mythical city of Tar. Based on Jodorowsky's memories of a play by surrealist Fernando Arrabal.", '1h 33min', 'Fando y Lis', '1968')
# ('tt0062503', '5,4', ['Peter Hall'], ['Jeremy Brooks', 'Henry Livings'], 'Añade un argumento en tu idioma\nEveryone is employed by the ultra-modern DICE Corporation, but Valentine Brose would rather stay at home to tend his psychedelic mushrooms.', '1h 33min', 'Work Is a Four Letter Word', '1968')
# ('tt0062729', '4,4', ['Alex Lovy'], ['Cal Howard'], 'Añade un argumento en tu idioma\nColonel Rimfire chases Cool Cat into a deserted house. Unfortunately, they are not alone. A ghost tries to befriend the two, but neither of them want to be friends with him because he is a spook.', '6min', 'Big Game Haunt', '1968')
# ('tt0062803', '6,9', ['Ken Hughes'], ['Ian Fleming', 'Roald Dahl', 'Ken Hughes'], 'Un inventor con poca suerte convierte un viejo coche de carreras en un fantástico vehículo para la familia, y se embarca con sus hijos en una mágica aventura fantástica para salvar a su abuelo en una tierra lejana.', '2h 24min', 'Chitty Chitty Bang Bang', '1968')
# ('tt0062737', '6,8', ['Robert Stevenson'], ['Bill Walsh', 'Don DaGradi', 'Ben Stahl'], 'Un entrenador universitario compra un calentador de camas antiguo, heredando así el travieso fantasma del conocido pirata Barbanegra que está condenado a quedarse en el limbo hasta que realice una buena acción.', '1h 46min', 'Mi amigo el fantasma', '1968')
# ('tt0063023', '8,7', ['Satyajit Ray'], ['Satyajit Ray', 'Upendra Kishore Raychowdhuri'], 'Añade un argumento en tu idioma\nGoopy wants to sing, and Bagha wants to play the dhol. They meet accidentally and are helped by King of Ghosts. With newly endowed abilities, they land in kingdom of Shundi, where their adventure begins.', '2h 12min', 'Goopy Gyne Bagha Byne', '1969')
# ('tt0062743', '5,8', ['Gilberto Martínez Solares'], ['Raúl Martínez Solares', 'Rafael Pérez Grovas'], 'Añade un argumento en tu idioma\nBlue Demon must battle against a group of alien women looking to kidnap men from planet earth.', '1h 27min', 'Blue Demon y las invasoras', '1969')
# ('tt0063340', '5,2', ['Tinto Brass'], ['Tinto Brass', 'Gian Carlo Fusco', 'Francesco Longo'], "Añade un argumento en tu idioma\nA taboo-smasher of the late '60s, featuring interracial affairs, anti-Vietnam statements, violence versus sex. Take a whirlwind trip with a married woman whose journey through the psychedelic English youth scene awakens her to the carnal offerings of an African-American man, all set to a searing soundtrack by Freedom, a tripped-out group formed from the remnants of Pr... Leer todo", '1h 17min', 'Nerosubianco', '1969')
# ('tt0063699', '6,6', ['Elisabeta Bostan', 'Nicolae Codrescu'], ['Elisabeta Bostan', 'Ion Creanga', 'Jane Wagner'], "Añade un argumento en tu idioma\nA young man's quest for a kingdom promising eternal youth and immortality. To reach his goal he must fulfill the three wishes of the Emperor's daughter, retrieve three golden objects and answer three riddles set by the Lord of Time", '1h 27min', 'Tinerete fara batrînete', '1969')
# ('tt0063216', '7,2', ['Apollinari Dudko', 'Konstantin Sergeyev'], ['Yelena Yevteyeva', 'John Markovsky', 'Makhmud Esambayev'], 'Añade un argumento en tu idioma\nThe sorcerer, rejected by the princess, turns her into a swan. Screen adaptation of the ballet of the same name by Pyotr Ilyich Tchaikovsky.', '1h 18min', 'El lago de los cisnes', '1969')
# ('tt0064258', '6,5', ['Wei Lo'], ['Wei Lo'], 'Añade un argumento en tu idioma\nAfter being implicated in the theft of the Jade Dragon Sword, Fan Ying is banished to the Dragon Swamp for 20 years.', '1h 45min', 'Du long tan', '1969')
# ('tt0064443', '4,7', ['Michael Armstrong'], ['Michael Armstrong', 'Gerry Levy'], 'Añade un argumento en tu idioma\nTeenagers gathered in an old mansion are being murdered one by one. The survivors must discover who among them is the killer before he finishes off everybody.', '1h 32min', 'Crímenes en la oscuridad', '1969')
# ('tt0064425', '6,6', ['Édouard Molinaro'], ['Jean Bernard-Luc', 'Jacques Vilfrid', 'Louis de Funès'], 'Un rico hombre de negocios se enfrenta a un problema bastante extraño: el abuelo de su mujer ha revivido gracias a la ciencia. Pero él no es consciente de que han pasado muchas décadas.', '1h 22min', 'El abuelo congelado', '1969')
# ('tt0060477', '7,3', ['Gilberto Martínez Solares'], ['Joel Harrison', 'Gilberto Martínez Solares', 'John Anderson'], 'Añade un argumento en tu idioma\nAn alcoholic janitor is fired from his job at an orphanage, and is befriended by an angel in the guise of a little girl, who proceeds to change his life.', '1h 35min', 'Gregorio y su ángel', '1970')
# ('tt0062701', '6,0', ['Pupi Avati'], ['Pupi Avati', 'Giorgio Celli', 'Enzo Leonardi'], "Añade un argumento en tu idioma\nThe story about a sinister magician-dwarf, physically unable to love a woman. His wife's betrayals and an obsessive isolation drive him to despair.", '1h 39min', "Balsamus l'uomo di Satana", '1970')
# ('tt0064190', '6,7', ['Alejandro Galindo'], ['Alejandro Galindo', 'Enrique Rosado'], 'Añade un argumento en tu idioma', '1h 30min', 'Cristo 70', '1970')
# ('tt0064843', '7,0', ['Pavel Jurácek'], ['Pavel Jurácek', 'Jonathan Swift'], 'Añade un argumento en tu idioma\nLemuel Gulliver (Lubomír Kostelka) has had a car accident and continues his journey across the unknown countryside on foot. On the road he finds a dead rabbit dressed like a man and takes a watch from its waistcoat breast pocket. The half-ruined house that he enters reminds Lemuel of his childhood and brings up a painful memory of a dearly loved girl Markéta who was d... Leer todo', '1h 47min', 'Prípad pro zacínajícího kata', '1970')
# ('tt0065050', '8,5', ['Murray Woroner'], ['Rocky Marciano', 'Muhammad Ali', 'Jimmy Braddock'], 'Añade un argumento en tu idioma\nFictional boxing match between two of the greatest heavyweights of all time.', '1h 10min', 'The Super Fight', '1970')
# ('tt0064806', '6,7', ['Chuck Jones', 'Abe Levitow', 'Dave Monahan'], ['Chuck Jones', 'Sam Rosen', 'Norton Juster'], 'Añade un argumento en tu idioma\nMilo is a boy who is bored with life. One day he comes home to find a toll booth in his room. Having nothing better to do, he gets in his toy car and drives through - only to emerge in a world full of adventure.', '1h 30min', 'La puerta mágica', '1970')
# ('tt0064932', '6,0', ['Gilberto Martínez Solares'], ['Rafael García Travesi', 'Jesús Sotomayor Martínez'], 'Añade un argumento en tu idioma\nTo foil his plan for world domination, wrestling superheroes El Santo and Blue Demon battle the mad Dr. Halder and his army of reanimated monsters.', '1h 25min', 'Santo el enmascarado de plata y Blue Demon contra los monstruos', '1970')
# ('tt0064554', '6,6', ['Pavel Arsenov'], ['Carlo Gozzi', 'Vadim Korostylyov'], "Añade un argumento en tu idioma\nDeramo, kind, but simple-hearted king of Serendippe, wishes to marry. But here's the problem: how to find out which of the contenders really loves Deramo, and which one simply counts on the royal throne? The wizard Durandarte gives the king a statue of a fool who laughs if someone says untruth. Outwardly, the idiot is similar to the favorite of the king by the first m... Leer todo", '1h 17min', 'Korol-olen', '1970')
# ('tt0065073', '6,3', ['Peter Sasdy'], ['Anthony Hinds', 'Bram Stoker'], 'Añade un argumento en tu idioma\nAfter killing his disciple, three English gentlemen unwittingly resurrect Count Dracula, who seeks to avenge his servant by making the trio die by the hands of their own children.', '1h 31min', 'El poder de la sangre de Drácula', '1970')

# %%
#Pasamos la informacion a un DataFrame
df_details = pd.DataFrame(movie_list, columns= ["idOwner", "imdb_rating", "direction", "writers", "plot", "length", "name", "year"])

# %%
# Comprobamos la informacion en el DataFrame
df_details
# Out:
#        idOwner imdb_rating                                 direction  \
# 0    tt0052698         7,5                           [Claude Sautet]
# 1    tt0053357         5,5                          [Edward L. Cahn]
# 2    tt0052661         6,1                       [Alfred Weidenmann]
# 3    tt0053228         6,2                           [Jürgen Roland]
# 4    tt0053752         6,6                         [John Guillermin]
# ..         ...         ...                                       ...
# 219  tt0065050         8,5                          [Murray Woroner]
# 220  tt0064806         6,7  [Chuck Jones, Abe Levitow, Dave Monahan]
# 221  tt0064932         6,0               [Gilberto Martínez Solares]
# 222  tt0064554         6,6                           [Pavel Arsenov]
# 223  tt0065073         6,3                             [Peter Sasdy]
#
#                                                writers  \
# 0        [José Giovanni, Claude Sautet, Pascal Jardin]
# 1                 [Robert E. Kent, Orville H. Hampton]
# 2                   [Herbert Reinecker, Igor Sentjurc]
# 3            [Edgar Wallace, Egon Eis, Wolfgang Menge]
# 4        [John Brophy, Howard Clewes, Richard Maibaum]
# ..                                                 ...
# 219     [Rocky Marciano, Muhammad Ali, Jimmy Braddock]
# 220            [Chuck Jones, Sam Rosen, Norton Juster]
# 221  [Rafael García Travesi, Jesús Sotomayor Martínez]
# 222                   [Carlo Gozzi, Vadim Korostylyov]
# 223                       [Anthony Hinds, Bram Stoker]
#
#                                                   plot    length  \
# 0    Un despiadado criminal huye de la persecución,...  1h 50min
# 1    Tres asesinos profesionales irrumpen en la cas...  1h 11min
# 2                      Añade un argumento en tu idioma  1h 32min
# 3    Añade un argumento en tu idioma\nA strange, re...  1h 32min
# 4    Añade un argumento en tu idioma\nIn 1901, a gr...  1h 25min
# ..                                                 ...       ...
# 219  Añade un argumento en tu idioma\nFictional box...  1h 10min
# 220  Añade un argumento en tu idioma\nMilo is a boy...  1h 30min
# 221  Añade un argumento en tu idioma\nTo foil his p...  1h 25min
# 222  Añade un argumento en tu idioma\nDeramo, kind,...  1h 17min
# 223  Añade un argumento en tu idioma\nAfter killing...  1h 31min
#
#                                                   name  year
# 0                                        A todo riesgo  1960
# 1                                   Three Came to Kill  1960
# 2                            Las dos caras del destino  1960
# 3                                      El círculo rojo  1960
# 4                       El robo al banco de Inglaterra  1960
# ..                                                 ...   ...
# 219                                    The Super Fight  1970
# 220                                   La puerta mágica  1970
# 221  Santo el enmascarado de plata y Blue Demon con...  1970
# 222                                         Korol-olen  1970
# 223                   El poder de la sangre de Drácula  1970
#
# [224 rows x 8 columns]

# %%
#Pasamos todo a un CSV para poder trabajar con la informacion
df_details.to_csv("film_details.csv", index = False)
