# %%
# Importar librería para la conexión con MySQL
# -----------------------------------------------------------------------
import mysql.connector
from mysql.connector import errorcode
from mysql.connector import Error


# Importar librerías para manipulación y análisis de datos
# -----------------------------------------------------------------------
import pandas as pd

# %%
# probar la conexion
cnx = mysql.connector.connect(user='root', password='AlumnaAdalab',
                              host='127.0.0.1', database='proyecto2_equipo1_v2')


try:
    mycursor = cnx.cursor()
    
except mysql.connector.Error as err:
    print(err)
    print("Error Code:", err.errno)
    print("SQLSTATE", err.sqlstate)
    print("Message", err.msg)
cnx.close()

# %%
# Insertar datos Tabla Oscars
cnx = mysql.connector.connect(user='root', password='AlumnaAdalab',
                              host='127.0.0.1', database='proyecto2_equipo1_v2')

mycursor = cnx.cursor()

## Leer el archivo CSV
data_movies = pd.read_csv('oscars.csv')

## Unir dos dataframes
#df = pd.merge(data_movies, data_movies_details, on="id", how="inner")
#df

query = """INSERT INTO Oscars 
           (gala_date, best_movie, best_director, best_actor, best_actress) 
           VALUES (%s, %s, %s, %s, %s)"""

## Insertar los datos en la tabla
# Insertar cada fila en la base de datos
for _, row in data_movies.iterrows():
    try:
        mycursor.execute(query, tuple(row))
    except mysql.connector.Error as err:
        print(f"Error insertando fila {row['id']}: {err}")

# Confirmar los cambios en la base de datos
cnx.commit()

# Cerrar el cursor y la conexión
mycursor.close()
cnx.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 8
#       5 mycursor = cnx.cursor()
#       7 ## Leer el archivo CSV
# ----> 8 data_movies = pd.read_csv('oscars.csv')
#      10 ## Unir dos dataframes
#      11 #df = pd.merge(data_movies, data_movies_details, on="id", how="inner")
#      12 #df
#      14 query = """INSERT INTO Oscars
#      15            (gala_date, best_movie, best_director, best_actor, best_actress)
#      16            VALUES (%s, %s, %s, %s, %s)"""
#
# ...

# %%
# Insertar detalles de películas
# Conectar a la base de datos
cnx = mysql.connector.connect(user='root', password='AlumnaAdalab',
                              host='127.0.0.1', database='proyecto2_equipo1_v2')

mycursor = cnx.cursor()

# Leer el archivo CSV
data_film_details = pd.read_csv('film_details.csv')

# Revisar nombres de las columnas
print(data_film_details.columns)

# Query de inserción
query = """INSERT INTO film_details
           (idOwner, imdb_rating, direction, writers, plot, length, name, year)
           VALUES (%s, %s, %s, %s, %s, %s, %s, %s)"""

# Insertar los datos en la tabla
for _, row in data_film_details.iterrows():
    try:
        print(f"Inserting row: {row['idOwner']}, {row['imdb_rating']}, {row['direction']}, {row['writers']}, {row['plot']}, {row['length']}, {row['name']}, {row['year']}")
        mycursor.execute(query, (row['idOwner'], row['imdb_rating'], row['direction'],
                                 row['writers'], row['plot'], row['length'], row['name'],
                                 row['year']))
    except mysql.connector.Error as err:
        print(f"Error insertando fila {row['idOwner']}: {err}")

# Confirmar los cambios en la base de datos
cnx.commit()

# Cerrar el cursor y la conexión
mycursor.close()
cnx.close()
# Out:
# Index(['idOwner', 'imdb_rating', 'direction', 'writers', 'plot', 'length',
#        'name', 'year'],
#       dtype='object')
# Inserting row: tt0052698, 7,5, ['Claude Sautet'], ['José Giovanni', 'Claude Sautet', 'Pascal Jardin'], Un despiadado criminal huye de la persecución, lo que implica cada vez más víctimas., 1h 50min, A todo riesgo, 1960.0
# Inserting row: tt0053357, 5,5, ['Edward L. Cahn'], ['Robert E. Kent', 'Orville H. Hampton'], Tres asesinos profesionales irrumpen en la casa de un empleado del aeropuerto para disparar al avión en el que un primer ministro asiático debe abandonar Estados Unidos., 1h 11min, Three Came to Kill, 1960.0
# Inserting row: tt0052661, 6,1, ['Alfred Weidenmann'], ['Herbert Reinecker', 'Igor Sentjurc'], Añade un argumento en tu idioma, 1h 32min, Las dos caras del destino, 1960.0
# Inserting row: tt0053228, 6,2, ['Jürgen Roland'], ['Edgar Wallace', 'Egon Eis', 'Wolfgang Menge'], Añade un argumento en tu idioma
# ...

# %%
# Insertar películas

# Conectar a la base de datos
cnx = mysql.connector.connect(user='root', password='AlumnaAdalab',
                              host='127.0.0.1', database='proyecto2_equipo1_v2')

mycursor = cnx.cursor()

# Leer el archivo CSV
data_film = pd.read_csv('film.csv')

# Revisar nombres de las columnas
print(data_film.columns)

# Query de inserción
query = """INSERT INTO film
           (title, type, year, genre, idOwner)
           VALUES (%s, %s, %s, %s, %s)"""

# Insertar los datos en la tabla
for _, row in data_film.iterrows():
    try:
        print(f"Inserting row: {row['title']}, {row['type']}, {row['year']}, {row['genre']}, {row['idOwner']}")
        mycursor.execute(query, (row['title'], row['type'], row['year'],
                                 row['genre'], row['idOwner']))
    except mysql.connector.Error as err:
        print(f"Error insertando fila {row['idOwner']}: {err}")

# Confirmar los cambios en la base de datos
cnx.commit()

# Cerrar el cursor y la conexión
mycursor.close()
cnx.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 10
#       7 mycursor = cnx.cursor()
#       9 # Leer el archivo CSV
# ---> 10 data_film = pd.read_csv('film.csv')
#      12 # Revisar nombres de las columnas
#      13 print(data_film.columns)
#
# ...

# %%
def delete_rows_based_on_condition(column_value):
    try:
        # Step 1: Establish a connection to the database
        connection = mysql.connector.connect(
            host='127.0.0.1',       # e.g., 'localhost'
            database='proyecto2_equipo1_v2',     # e.g., 'test_db'
            user='root',   # e.g., 'root'
            password='AlumnaAdalab'  # e.g., 'password'
        )
       
        if connection.is_connected():
            print("Successfully connected to the database")
           
            # Step 2: Prepare a cursor object
            cursor = connection.cursor()

            # Step 3: Prepare the DELETE query
            delete_query = """
            DELETE FROM film
            WHERE type = %s
            """
           
            # Step 4: Execute the DELETE query
            cursor.execute(delete_query, (column_value,))
           
            # Commit the transaction
            connection.commit()
            print(f"Rows deleted successfully where your_column = {column_value}")
       
    except Error as e:
        print(f"Error: {e}")
    finally:
        if connection.is_connected():
            cursor.close()
            connection.close()
            print("MySQL connection is closed")

# Replace 'your_column_value' with the value based on which you want to delete rows
delete_rows_based_on_condition('TV Short')
# Out:
# Successfully connected to the database
# Rows deleted successfully where your_column = TV Short
# MySQL connection is closed

# %%
# Insertar actores

# Conectar a la base de datos
cnx = mysql.connector.connect(user='root', password='AlumnaAdalab',
                              host='127.0.0.1', database='proyecto2_equipo1_v2')

mycursor = cnx.cursor()

# Leer el archivo CSV
data_actor = pd.read_csv('actors.csv')

# Revisar nombres de las columnas
print(data_actor.columns)

# Query de inserción
query = """INSERT INTO actor
           (actor_id, name, year_birthday, films_done, jobs, awards)
           VALUES (%s, %s, %s, %s, %s, %s)"""

# Insertar los datos en la tabla
for _, row in data_actor.iterrows():
    try:
        print(f"Inserting row: {row['actor_id']}, {row['name']}, {row['year_birthday']}, {row['films_done']}, {row['jobs']}, {row['awards']}")
        mycursor.execute(query, (row['actor_id'], row['name'], row['year_birthday'], row['films_done'], row['jobs'], row['awards']))
    except mysql.connector.Error as err:
        print(f"Error insertando fila {row['name']}: {err}")

# Confirmar los cambios en la base de datos
cnx.commit()

# Cerrar el cursor y la conexión
mycursor.close()
cnx.close()
# Out:
# Index(['actor_id', 'name', 'year_birthday', 'films_done', 'jobs', 'awards'], dtype='object')
# Inserting row: nm0893341, Lino Ventura, 1919, ['El ejército de las sombras', 'Ascensor para el cadalso', 'Una dama y un bribón', 'Los miserables'], ['Reparto', 'Banda sonora'], 3
# Inserting row: nm0590452, Sandra Milo, 1933, ['Fellini 8½', 'Giulietta de los espíritus', 'Adua y sus amigas', 'La entrevista'], ['Reparto', 'Equipos adicionales'], 6
# Inserting row: nm0000901, Jean-Paul Belmondo, 1933, ['Pierrot, el loco', 'Léon Morin, sacerdote', 'Al final de la escapada', 'Casino Royale'], ['Reparto', 'Producción', 'Especialistas'], 6
# Inserting row: nm0197950, Marcel Dalio, 1899, ['Sabrina', 'La regla del juego', 'Tener y no tener', 'Cómo robar un millón y...'], ['Reparto', 'Equipos adicionales', 'Guion'], 0
# Inserting row: nm0033929, Michel Ardan, Not found, ['Les bidasses en vadrouille', 'La grande nouba', 'A todo riesgo', 'La grande java'], ['Reparto', 'Producción', 'Guion'], 0
# ...

# %%
! pip install sqlalchemy
# Out:
# ...
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---- ----------------------------------- 0.2/2.1 MB 6.4 MB/s eta 0:00:01
#    ------- -------------------------------- 0.4/2.1 MB 2.8 MB/s eta 0:00:01
#    ------------ --------------------------- 0.7/2.1 MB 3.8 MB/s eta 0:00:01
#    ------------------- -------------------- 1.0/2.1 MB 4.2 MB/s eta 0:00:01
#    ------------------------- -------------- 1.4/2.1 MB 4.8 MB/s eta 0:00:01
#    -------------------------------- ------- 1.7/2.1 MB 4.9 MB/s eta 0:00:01
#    ------------------------------------- -- 2.0/2.1 MB 5.2 MB/s eta 0:00:01
#    ---------------------------------------  2.1/2.1 MB 5.3 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 4.7 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/292.8 kB ? eta -:--:--
#    ---------------------------------------- 292.8/292.8 kB 4.5 MB/s eta 0:00:00
# ...
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# ...

# %%
from sqlalchemy import create_engine

# %%
data = pd.read_csv("Movie_actor.csv")

# %%
engine = create_engine('mysql+mysqlconnector://root:AlumnaAdalab@127.0.0.1/proyecto2_equipo1_v2')

# %%
data.to_sql('Movie_actor', engine, if_exists='append', index=False)

# %%
# Insertar actores

# Conectar a la base de datos
cnx = mysql.connector.connect(user='root', password='AlumnaAdalab',
                              host='127.0.0.1', database='proyecto2_equipo1_v2')

mycursor = cnx.cursor()

# Leer el archivo CSV
Movie_actor = pd.read_csv('Movie_actor.csv')

# Revisar nombres de las columnas
print(Movie_actor.columns)

# Query de inserción
query = """INSERT INTO Movie_actor
           (id_pelicula, actor_id)
           VALUES (%s, %s)"""

# Insertar los datos en la tabla
for _, row in Movie_actor.iterrows():
    try:
        print(f"Inserting row: {row['id_pelicula']}, {row['actor_id']}")
        mycursor.execute(query, (row['id_pelicula'], row['actor_id']))
    except mysql.connector.Error as err:
        print(f"Error insertando fila {row['name']}: {err}")

# Confirmar los cambios en la base de datos
cnx.commit()

# Cerrar el cursor y la conexión
mycursor.close()
cnx.close()
# Out:
# Index(['id_pelicula', 'actor_id'], dtype='object')
# Inserting row: tt0052698, nm0893341
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File c:\Users\Nerea\anaconda3\Lib\site-packages\mysql\connector\connection_cext.py:697, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string)
#     696         query = query.encode("utf-8")
# --> 697     self._cmysql.query(
#     698         query,
#     699         raw=raw,
#     700         buffered=buffered,
#     701         raw_as_string=raw_as_string,
#     702         query_attrs=self.query_attrs,
#     703     )
#     704 except MySQLInterfaceError as err:
#
# MySQLInterfaceError: Unknown column 'id_pelicula' in 'field list'
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# Cell In[26], line 24
# ...

# %%
# CODIGO SQL PARA GENERAR LA BASE DE DATOS

-- MySQL Workbench Forward Engineering

SET @OLD_UNIQUE_CHECKS=@@UNIQUE_CHECKS, UNIQUE_CHECKS=0;
SET @OLD_FOREIGN_KEY_CHECKS=@@FOREIGN_KEY_CHECKS, FOREIGN_KEY_CHECKS=0;
SET @OLD_SQL_MODE=@@SQL_MODE, SQL_MODE='ONLY_FULL_GROUP_BY,STRICT_TRANS_TABLES,NO_ZERO_IN_DATE,NO_ZERO_DATE,ERROR_FOR_DIVISION_BY_ZERO,NO_ENGINE_SUBSTITUTION';

-- -----------------------------------------------------
-- Schema mydb
-- -----------------------------------------------------
-- -----------------------------------------------------
-- Schema proyecto2_equipo1
-- -----------------------------------------------------

-- -----------------------------------------------------
-- Schema proyecto2_equipo1
-- -----------------------------------------------------
CREATE SCHEMA IF NOT EXISTS `proyecto2_equipo1_v2` DEFAULT CHARACTER SET utf8 ;
USE `proyecto2_equipo1_v2` ;

-- -----------------------------------------------------
-- Table `proyecto2_equipo1`.`film_details`
-- -----------------------------------------------------
CREATE TABLE IF NOT EXISTS `proyecto2_equipo1_v2`.`film_details` (
  `id_details` INT NOT NULL AUTO_INCREMENT,
  `idOwner` VARCHAR(25) NOT NULL,
  `imdb_rating` VARCHAR(45) NULL DEFAULT NULL,
  `direction` VARCHAR(500) NULL DEFAULT NULL,
  `writers` VARCHAR(500) NULL DEFAULT NULL,
  `plot` VARCHAR(500) NULL DEFAULT NULL,
  `length` VARCHAR(100) NULL DEFAULT NULL,
  `name` VARCHAR(200) NULL DEFAULT NULL,
  `year` VARCHAR(25) NULL DEFAULT NULL,
  PRIMARY KEY (`id_details`))
ENGINE = InnoDB
AUTO_INCREMENT = 28
DEFAULT CHARACTER SET = utf8mb4;


-- -----------------------------------------------------
-- Table `proyecto2_equipo1`.`film`
-- -----------------------------------------------------
CREATE TABLE IF NOT EXISTS `proyecto2_equipo1_v2`.`film` (
  `id_film` INT NOT NULL AUTO_INCREMENT,
  `type` VARCHAR(50) NULL DEFAULT NULL,
  `year` VARCHAR(45) NULL DEFAULT NULL,
  `genre` VARCHAR(40) NULL DEFAULT NULL,
  `idOwner` VARCHAR(25) NOT NULL,
  `title` VARCHAR(200) NULL DEFAULT NULL,
  
ENGINE = InnoDB
DEFAULT CHARACTER SET = utf8mb4;


-- -----------------------------------------------------
-- Table `proyecto2_equipo1`.`actor`
-- -----------------------------------------------------
CREATE TABLE IF NOT EXISTS `proyecto2_equipo1_v2`.`actor` (
  `actor_id` INT NOT NULL,
  `name` VARCHAR(100) NULL DEFAULT NULL,
  `year_birthday` VARCHAR(100) NULL DEFAULT NULL,
  `films_done` VARCHAR(500) NULL DEFAULT NULL,
  `jobs` VARCHAR(500) NULL DEFAULT NULL,
  `awards` VARCHAR(500) NULL DEFAULT NULL,
  PRIMARY KEY (`actor_id`))
ENGINE = InnoDB
DEFAULT CHARACTER SET = utf8mb4;


-- -----------------------------------------------------
-- Table `proyecto2_equipo1`.`Movie_actor`
-- -----------------------------------------------------
CREATE TABLE IF NOT EXISTS `proyecto2_equipo1_v2`.`Movie_actor` (
  `id_film` INT NOT NULL,
  `actor_id` INT NOT NULL,
  INDEX `film_actor_idx` (`id_film` ASC) VISIBLE,
  INDEX `movie_actor_actor _idx` (`actor_id` ASC) VISIBLE,
  CONSTRAINT `film_actor`
    FOREIGN KEY (`id_film`)
    REFERENCES `proyecto2_equipo1_v2`.`film` (`id_film`),
  CONSTRAINT `movie_actor_actor `
    FOREIGN KEY (`actor_id`)
    REFERENCES `proyecto2_equipo1_v2`.`actor` (`actor_id`))
ENGINE = InnoDB
DEFAULT CHARACTER SET = utf8mb4;


-- -----------------------------------------------------
-- Table `proyecto2_equipo1`.`Oscars`
-- -----------------------------------------------------
CREATE TABLE IF NOT EXISTS `proyecto2_equipo1_v2`.`Oscars` (
  `oscar_id` INT NOT NULL AUTO_INCREMENT,
  `gala_date` VARCHAR(45) NULL DEFAULT NULL,
  `best_movie` VARCHAR(45) NULL DEFAULT NULL,
  `best_director` VARCHAR(45) NULL DEFAULT NULL,
  `best_actor` VARCHAR(45) NULL DEFAULT NULL,
  `best_actress` VARCHAR(45) NULL DEFAULT NULL,
  PRIMARY KEY (`oscar_id`))
ENGINE = InnoDB
AUTO_INCREMENT = 49
DEFAULT CHARACTER SET = utf8mb4;


SET SQL_MODE=@OLD_SQL_MODE;
SET FOREIGN_KEY_CHECKS=@OLD_FOREIGN_KEY_CHECKS;
SET UNIQUE_CHECKS=@OLD_UNIQUE_CHECKS;
# Out:
#   Cell In[10], line 3
#     -- MySQL Workbench Forward Engineering
#              ^
# SyntaxError: invalid syntax
